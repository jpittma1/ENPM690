# %% [markdown]
# <a href="https://colab.research.google.com/github/jpittma1/ENPM690/blob/main/HW2_Tutorial_and_CMAC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# NAME - Jerry Pittman, Jr.
#
# UID - 117077120

# %% [markdown]
# # **Python Tutorial and Homework 2**

# %% [markdown]
# This Colab Notebook contains 2 sections. The first section is a Python Tutorial intended to make you familiar with Numpy and Colab functionalities. **This section will not be graded**.
#
# The second section is a coding assignment (Homework 2). **This section will be graded**

# %% [markdown]
# # 1.0 **Python Tutorial**
#
# This assignment section won't be graded but is intended as a tutorial to refresh the basics of python and its dependencies. It also allows one to get familiarized with Google Colab.

# %% [markdown]
# ## 1.0.0 Array manipulation using numpy

# %% [markdown]
# #### Q1 - Matrix multiplication

# %%
import numpy as np

### Create two numpy arrays with the dimensions 3x2 and 2x3 respectively using  np.arange(). 
### The elements of the vector are 
### Vector 1 elements = [ 2,  4,  6,  8, 10, 12]; 
### Vector 2 elements = [ 7, 10, 13, 16, 19, 22]

### Starting at 2, stepping by 2
vector1 = np.arange(2, 14,2).reshape((3, 2))
### Starting at 7, stepping by 3
vector2 = np.arange(7, 25,3).reshape((2,3))

### Print vec
print(vector1, vector2)

### Take product of the two matricies (Matrix product)
prod = np.matmul(vector1,vector2)

### Print
print(prod)
# Out:
# [[ 2  4]
#  [ 6  8]
#  [10 12]] [[ 7 10 13]
#  [16 19 22]]
# [[ 78  96 114]
#  [170 212 254]
#  [262 328 394]]

# %% [markdown]
# #### Q2 - Diagonals

# %%
### Create two numpy arrays with the dimensions 10x10 using the function np.arange(). 
### Starting at 2, stepping by 3
stop1= 2+10*10*3
stop2 = 35+10*10*9
vector1 = np.arange(2, stop1, 3).reshape((10, 10))
### Starting at 35, stepping by 9
vector2 = np.arange(35, stop2,9).reshape((10,10))

### Print vec
print(vector1,vector2)

# [ 44 143 242 341 440 539 638 737 836]

### Obtain the diagonal matrix of each vector1 such that the start of the diagonal is from (3,0) and the end is (10,7)
### Reshape the the matrix such that it form a diagonal maritix of shape(7,7) 
vector1_offset_diagonal = np.diag(vector1, k=3) * np.eye(7,7)

### Obtain a 7x7 matrix from the vector 2 
### starting from (left top element) = (0,3)
### ending at (right bottom element) = (7,10)
vector2_offset_diagonal = np.diag(vector2, k=0)

clip = vector2_offset_diagonal[0:-3]

vector2_offset_diagonal = clip * np.eye(7,7)

### Print diagonal matrix
print(vector1_offset_diagonal, vector2_offset_diagonal)


### Take product of the two diagonal matricies (Matrix product)
prod = np.matmul(vector1_offset_diagonal, vector2_offset_diagonal)

### Print
print(prod)
# Out:
# [[  2   5   8  11  14  17  20  23  26  29]
#  [ 32  35  38  41  44  47  50  53  56  59]
#  [ 62  65  68  71  74  77  80  83  86  89]
#  [ 92  95  98 101 104 107 110 113 116 119]
#  [122 125 128 131 134 137 140 143 146 149]
#  [152 155 158 161 164 167 170 173 176 179]
#  [182 185 188 191 194 197 200 203 206 209]
#  [212 215 218 221 224 227 230 233 236 239]
#  [242 245 248 251 254 257 260 263 266 269]
#  [272 275 278 281 284 287 290 293 296 299]] [[ 35  44  53  62  71  80  89  98 107 116]
#  [125 134 143 152 161 170 179 188 197 206]
#  [215 224 233 242 251 260 269 278 287 296]
#  [305 314 323 332 341 350 359 368 377 386]
#  [395 404 413 422 431 440 449 458 467 476]
#  [485 494 503 512 521 530 539 548 557 566]
#  [575 584 593 602 611 620 629 638 647 656]
#  [665 674 683 692 701 710 719 728 737 746]
#  [755 764 773 782 791 800 809 818 827 836]
#  [845 854 863 872 881 890 899 908 917 926]]
# [[ 11.   0.   0.   0.   0.   0.   0.]
#  [  0.  44.   0.   0.   0.   0.   0.]
#  [  0.   0.  77.   0.   0.   0.   0.]
#  [  0.   0.   0. 110.   0.   0.   0.]
#  [  0.   0.   0.   0. 143.   0.   0.]
#  [  0.   0.   0.   0.   0. 176.   0.]
#  [  0.   0.   0.   0.   0.   0. 209.]] [[ 35.   0.   0.   0.   0.   0.   0.]
#  [  0. 134.   0.   0.   0.   0.   0.]
#  [  0.   0. 233.   0.   0.   0.   0.]
#  [  0.   0.   0. 332.   0.   0.   0.]
#  [  0.   0.   0.   0. 431.   0.   0.]
#  [  0.   0.   0.   0.   0. 530.   0.]
#  [  0.   0.   0.   0.   0.   0. 629.]]
# [[   385.      0.      0.      0.      0.      0.      0.]
#  [     0.   5896.      0.      0.      0.      0.      0.]
#  [     0.      0.  17941.      0.      0.      0.      0.]
#  [     0.      0.      0.  36520.      0.      0.      0.]
#  [     0.      0.      0.      0.  61633.      0.      0.]
#  [     0.      0.      0.      0.      0.  93280.      0.]
#  [     0.      0.      0.      0.      0.      0. 131461.]]

# %% [markdown]
# #### Q3 - Sin wave

# %% [markdown]
# Sample outputs,
# ![download.png](data:image/png;base64,...) ![download (1).png](data:image/png;base64,...)

# %%
import matplotlib.pyplot as plt
### Create a time matrix that evenly samples a sine wave at a frequency of 1Hz
### Starting at time step T = 0
### End at time step T = 500
time = np.arange(0, 500, 1)


### Given wavelength of
wavelength = 500

### Construct a sin wave using the formula sin(2*pi*(time/wavelength))
pi = 3.14
y = np.sin(2*pi*(time/wavelength))

#### Plot the wave
plt.plot(time, y)
plt.show()

# %%
#### Given a 2D mesh grid
X, Y = np.meshgrid(time, time)
#### wavelength and angle of rotation(phi) of the sin wave in 2d. Imagine a 2D sine wave is being rotating about the Z axes
wavelength = 200
phi = np.pi / 3

#### Calculate the sin wave in 2d space using the formula sin(2*pi*(x'/wavelength)) where x'=Xcos(phi) + Ysin(phi)
x_prime=X *np.cos(phi) + Y* np.sin(phi)

grating =  np.sin(2*pi*(x_prime/wavelength))

# x=X*np.cos(phi) + Y* np.sin(phi)

#### Plot the wave
#### Intuition, think of the white area as hills and the black areas as valleys
plt.set_cmap("gray")
plt.imshow(grating)
plt.show()

# %% [markdown]
# #### Q4 Car Brands

# %%
import numpy as np

cars = ['Civic', 'Insight', 'Fit', 'Accord', 'Ridgeline', 'Avancier','Pilot', 'Legend', 'Beat', 'FR-V', 'HR-V', 'Shuttle']

#### Create a 3D array of cars of shape 2,3,2
cars_3d = np.array(cars).reshape((2,3,2)).transpose()

#### Extract the top layer of the matrix. Top layer of a matrix A of shape(2,3,2) will have the following structue A_top = [[A[0,0,0], A[0,0,1]],[A[0,1,0],A[0,1,1]],[A[0,2,0],A[0,2,1]]]
#### HINT - Array slicing or splitting
cars_top_layer = cars_3d[0,:,:]

#### Similarly extract the bottom layer
#### HINT - Array slicing or splitting
cars_bottom_layer = cars_3d[1,:,:]

#### Print layers
print("\nTop Layer \n ",cars_top_layer,"\nBottom Layer\n", cars_bottom_layer)

#### Flatten the top layer
cars_top_flat = cars_top_layer.flatten()
#### Flatten the bottom layer
cars_bottom_flat = cars_bottom_layer.flatten()

#### Print layers
print("\nTop Flattened : ",cars_top_flat,"\nBottom Flattened : ",cars_bottom_flat)


new_car_list = np.empty((cars_top_layer.size + cars_bottom_layer.size,), dtype=object)
#### Interweave the to flattened lists and insert into new_car_list such that new_car_list=['Civic' 'Pilot' 'Fit' 'Beat' 'Ridgeline' 'HR-V' 'Insight' 'Legend' 'Accord' 'FR-V' 'Avancier' 'Shuttle']
#### Using only array slicing
new_car_list[0:6] = cars_top_flat
new_car_list[6:12] = cars_bottom_flat
# new_car_list[0::1] = cars_top_flat
# new_car_list[1::2] = cars_bottom_flat


#### Concatenate and flatten the top and bottom layer such that the final list is of the form cat_flat = ['Civic' 'Insight' 'Pilot' 'Legend' 'Fit' 'Accord' 'Beat' 'FR-V' 'Ridgeline' 'Avancier' 'HR-V' 'Shuttle']
cat_flat = np.empty((cars_top_layer.size + cars_bottom_layer.size,), dtype=object)


def catList(lst1, lst2):
    return [sub[item] for item in range(len(lst2))
                      for sub in [lst1, lst2]]
cat_flat = catList(cars_top_flat, cars_bottom_flat)

#### Print layers
print("\n\nInterwoven - ",new_car_list,"\nConcatenate and flatten - ", cat_flat)
# Out:
# Top Layer
#   [['Civic' 'Pilot']
#  ['Fit' 'Beat']
#  ['Ridgeline' 'HR-V']]
# Bottom Layer
#  [['Insight' 'Legend']
#  ['Accord' 'FR-V']
#  ['Avancier' 'Shuttle']]
#
# Top Flattened :  ['Civic' 'Pilot' 'Fit' 'Beat' 'Ridgeline' 'HR-V']
# Bottom Flattened :  ['Insight' 'Legend' 'Accord' 'FR-V' 'Avancier' 'Shuttle']
#
#
# Interwoven -  ['Civic' 'Pilot' 'Fit' 'Beat' 'Ridgeline' 'HR-V' 'Insight' 'Legend'
#  'Accord' 'FR-V' 'Avancier' 'Shuttle']
# Concatenate and flatten -  ['Civic', 'Insight', 'Pilot', 'Legend', 'Fit', 'Accord', 'Beat', 'FR-V', 'Ridgeline', 'Avancier', 'HR-V', 'Shuttle']

# %% [markdown]
# ## 1.0.1 Basics tensorflow

# %% [markdown]
# #### Helper functions

# %%
import tensorflow as tf
from keras.utils import to_categorical

# %%
def plot_image(i, predictions_array, true_label, img):
  true_label, img = true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

def plot_value_array(i, predictions_array, true_label):
  true_label = true_label[i]
  # print(true_label)
  plt.grid(False)
  plt.xticks(range(10))
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label].set_color('blue')

# %% [markdown]
# #### Q1 MNIST Classifier

# %%
## Import the MNIST dataset from keras
mnist = tf.keras.datasets.mnist
### Load the data
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# ### Normalize the 8bit images with values in the range [0,255]

def normalize_img(image):
  return tf.cast(image,tf.float32) / 255.

normalize_img(x_train)
# normalize_img(x_test)
normalize_img(y_train)
# normalize_img(y_test)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 3s 0us/step
# <tf.Tensor: shape=(60000,), dtype=float32, numpy=
# array([0.01960784, 0.        , 0.01568628, ..., 0.01960784, 0.02352941,
#        0.03137255], dtype=float32)>

# %%
## Create a model with the following architecture Flatten -> Dense(128, relu) -> Dense(64,relu) -> outpuLayer(size=10)
model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(input_shape=(28, 28)),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dense(64, activation='relu'),
  tf.keras.layers.Dense(10)
])
### Complie the model with the adam optimizer and crossentropy loss
### HINT - No One hot encoding
loss_fn = tf.keras.losses.SparseCategoricalCrossentropy()

model.compile(loss=loss_fn, optimizer='adam')

# %%
### Train the model on the train data for 5 epochs

model.fit(x_train, y_train, epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 14s 7ms/step - loss: 8.0575
# Epoch 2/5
# 1875/1875 [==============================] - 12s 7ms/step - loss: 2.3035
# Epoch 3/5
# 1875/1875 [==============================] - 13s 7ms/step - loss: 2.3035
# Epoch 4/5
# 1875/1875 [==============================] - 10s 5ms/step - loss: 2.3035
# Epoch 5/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 2.3035

# %%
### Check the accuracy of the trained model
# test_loss, test_acc = model.evaluate(x_test,  y_test, verbose=2)
test_acc = model.evaluate(x_test, y_test)
print('\nTest accuracy:', test_acc)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 2.3041
#
# Test accuracy: 2.304086446762085

# %%
import numpy as np
import tensorflow as tf
from keras.utils import to_categorical
import tensorflow_probability as tfp

import matplotlib.pyplot as plt

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Dropout
from tensorflow.keras.losses import SparseCategoricalCrossentropy
from tensorflow.keras.optimizers import RMSprop

tfd = tfp.distributions
tfpl = tfp.layers

### Convert the above model to a probabilistic model with a softmax as the output layer

def get_probabilistic_model(input_shape, loss, optimizer, metrics):
    """
    This function should return the probabilistic model according to the 
    above specification.
    The function takes input_shape, loss, optimizer and metrics as arguments, which should be
    used to define and compile the model.
    Your function should return the compiled model.
    """
    model = Sequential([
        Conv2D(28, kernel_size=(3, 3), input_shape=input_shape),
        MaxPooling2D(pool_size=(2, 2)),
        Flatten(),
        Dense(128, activation=tf.nn.relu),
        Dense(tfpl.OneHotCategorical.params_size(28)),
        Dropout(0.2),
        Dense(10, activation=tf.keras.activations.softmax)
    ])
    
    model.compile(loss=loss, optimizer=optimizer, metrics=metrics)
    return model

loss_fn = tf.keras.losses.SparseCategoricalCrossentropy()

tf.random.set_seed(0)
probabilistic_model = get_probabilistic_model(
    input_shape=(28, 28, 1), 
    loss=loss_fn, 
    optimizer=RMSprop(), 
    metrics=['accuracy']
)


# ### Run the test data through the new model and get predictions

probabilistic_model.fit(x=x_train,y=y_train, epochs=10)

predictions = probabilistic_model.predict(x_train, verbose=0)

# probabilistic_model.fit(x_train, y_train,
#       batch_size=batch_size,
#       epochs=epochs,
#       verbose=1,
#       validation_data=(x_test, y_test))
# score = probabilistic_model.evaluate(x_test, y_test, verbose=0)
# print('Test loss:', score[0])
# print('Test accuracy:', score[1])


### Plot a test output 
i = 25  ### <---- Change this to some random number to see different predictions

print("compare predicted ",predictions[i].argmax(), ", to expected ",y_test[i])

plt.figure(figsize=(6,3))
plt.subplot(1,2,1)
plot_image(i, predictions[i], y_test, x_test)
plt.subplot(1,2,2)
plot_value_array(i, predictions[i], y_test)
plt.show()
print(predictions[i].argmax())
### Blue bars mean correct guess red bar means wrong guess!!
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 74s 39ms/step - loss: 1.1228 - accuracy: 0.8930
# Epoch 2/10
# 1875/1875 [==============================] - 80s 43ms/step - loss: 0.1867 - accuracy: 0.9567
# Epoch 3/10
# 1875/1875 [==============================] - 74s 40ms/step - loss: 0.1320 - accuracy: 0.9678
# Epoch 4/10
# 1875/1875 [==============================] - 76s 41ms/step - loss: 0.1024 - accuracy: 0.9747
# Epoch 5/10
# 1875/1875 [==============================] - 72s 38ms/step - loss: 0.0834 - accuracy: 0.9780
# Epoch 6/10
# 1875/1875 [==============================] - 72s 38ms/step - loss: 0.0718 - accuracy: 0.9817
# Epoch 7/10
# 1875/1875 [==============================] - 75s 40ms/step - loss: 0.0644 - accuracy: 0.9840
# Epoch 8/10
# 1875/1875 [==============================] - 76s 41ms/step - loss: 0.0561 - accuracy: 0.9868
# Epoch 9/10
# 1875/1875 [==============================] - 74s 39ms/step - loss: 0.0531 - accuracy: 0.9873
# Epoch 10/10
# 1875/1875 [==============================] - 75s 40ms/step - loss: 0.0504 - accuracy: 0.9885
# compare predicted  2 , to expected  0
# 2

# %% [markdown]
# # 2.0 **Homework 2**
# *Note : This section will be graded*

# %% [markdown]
# 1. Program a Discrete CMAC and train it on a 1-D function (ref: Albus 1975, Fig. 5)
# Explore effect of overlap area on generalization and time to convergence.
# Use only 35 weights weights for your CMAC, and sample your function at 100
# evenly spaced points. Use 70 for training and 30 for testing. Report the
# accuracy of your CMAC network using only the 30 test points.

# %%
import numpy as np
import matplotlib.pyplot as plt
import math
import time

# %%
'''CMAC Parent Class'''
class CMAC:
    def __init__(self, gen_factor, num_weights):
        self.gen_factor = gen_factor
        self.num_weights = num_weights
        self.weight_vec = np.ones(self.num_weights)
        self.association_map = {}

    def set_gen_factor(self, gen_factor):
        self.gen_factor = gen_factor

# %%
# Child Inherited class for Discrete CMAC
class DiscreteCMAC(CMAC):

    def __init__(self, gen_factor, num_weights):
        CMAC.__init__(self, gen_factor, num_weights)

    '''This will return the index (or the ith sample), in the association_input_vec values, 
    corresponding the actual input value'''
    def get_assoc_vec_ind(self, input_val, num_of_assoc_vec, input_min, input_max):
        if input_val < input_min:
            return 1
        elif input_val > input_max:
            return num_of_assoc_vec-1
        else:
            proportion_ind = (num_of_assoc_vec-2) * ((input_val - input_min)/(input_max - input_min)) + 1
            return proportion_ind


    '''Association map in CMAC is an assiociation unit matrix of size (m x n),
        where m = number of association input vectors (possible values of the sample input)
        n = number of weights
        
        >> This function will return a map with: 
                key = specific sample input value 
                value = index of the first cell in the range of consecutive ones in that row (corresponding to the input value) 
    '''
    def process_association_map(self, data, input_min, input_max):
        num_of_assoc_vec = self.num_weights + 1 - self.gen_factor
        for ind, data_val in enumerate(data):
            assoc_vec_ind = self.get_assoc_vec_ind(data_val[0], num_of_assoc_vec, input_min, input_max)
            self.association_map[data_val[0]] = int(math.floor(assoc_vec_ind))

    
    def train(self, data, input_min, input_max, total_epoch = 5000, learning_rate = 0.01):
        self.weight_vec = np.ones(self.num_weights) 
        input_X = np.linspace(input_min, input_max, self.num_weights + 1 - self.gen_factor)
        alpha = learning_rate
        epoch = 0

        self.association_map = {}
        self.process_association_map(data, input_min, input_max)

        is_converged = False
        prev_error = 0
        new_error = 0
        start_time = time.time()
        while epoch <= total_epoch and not is_converged:
            prev_error = new_error
            for ind, data_val in enumerate(data):
                asc_wt_ind = self.association_map[data_val[0]]
                y_output = np.sum(self.weight_vec[asc_wt_ind: asc_wt_ind + self.gen_factor])
                error = data_val[1] - y_output
                correction = alpha*error/self.gen_factor
                self.weight_vec[asc_wt_ind: (asc_wt_ind + self.gen_factor)] = [(self.weight_vec[ind] + correction) for ind in range(asc_wt_ind, (asc_wt_ind + self.gen_factor))]
            
            
            intermediate_output, accuracy = self.predict(data, input_min, input_max, False)
            new_error = 1 - accuracy
            if np.abs(prev_error - new_error) < 0.0000001:
                is_converged = True
            
            epoch = epoch + 1
            print("Discrete CMAC: ", " => g -", self.gen_factor ,"epoch - ", epoch, "  => error - ", new_error, " accuracy - ", accuracy*100)
        
        end_time = time.time()
        process_time = end_time - start_time
        return process_time, np.copy(self.weight_vec)

    def calculate_error(self, y_predict, y_expected):
        error = np.subtract(y_expected, y_predict)
        error_sq = np.power(error, 2)
        sum_error_sq = np.sum(error_sq)
        total_error = np.sqrt(sum_error_sq)/len(y_expected)
        return total_error
    
    def predict(self, data, input_min, input_max, re_process_asso_map = True):
        output = []
        if re_process_asso_map:
            self.process_association_map(data, input_min, input_max)

        for ind, data_val in enumerate(data):
            asc_wt_ind = self.association_map[data_val[0]]
            y_output = np.sum(self.weight_vec[asc_wt_ind: asc_wt_ind + self.gen_factor])
            output.append(y_output)
        
        error = self.calculate_error(output, data[:, 1])
        accuracy = 1 - error
        return output, accuracy

# %%
#main

# 1D function: sin(x)
TWO_PI = 2*np.pi #create data
sample_input = np.linspace(0, TWO_PI, 100) #100 evenly spaced sample points
sample_output = np.sin(sample_input)

total_data = np.column_stack((sample_input, sample_output))
np.random.shuffle(total_data)

train_data = total_data[:70]
test_data = total_data[70:] #30 data points

x_train = train_data[:, 0]
x_test = test_data[:, 0]

y_train = train_data[:, 1]
y_test = test_data[:, 1] 

num_weights = 35

gen_factor_list = range(1, num_weights)

convergence_time_discrete = []
accuracies_discrete = []

#create class Object
discrete_cmac = DiscreteCMAC(1, num_weights)

for gen_factor in gen_factor_list:
    discrete_cmac.set_gen_factor(gen_factor)
    process_time_discrete, weight_vec_discrete = discrete_cmac.train(train_data, 0, TWO_PI, 10000)
    y_output_discrete, accuracy_discrete = discrete_cmac.predict(test_data, 0, TWO_PI)

    convergence_time_discrete.append(process_time_discrete)
    accuracies_discrete.append(accuracy_discrete)

fig, (ax1, ax2) = plt.subplots(1, 2)
plt.style.use('seaborn-whitegrid')

ax1.set_title('Convergence time v/s Generalization Factor')
ax1.plot(gen_factor_list, convergence_time_discrete, label="Discrete CMAC")
ax1.set(xlabel='generalization factor', ylabel='Convergence time')
ax1.legend()
    

ax2.set_title('Accuracy v/s Generalization Factor')
ax2.plot(gen_factor_list, accuracies_discrete, label="Discrete CMAC")
ax2.set(xlabel='generalization factor', ylabel='Accuracy')
ax2.legend()

plt.show()
# Out:
# Streaming output truncated to the last 5000 lines.
# Discrete CMAC:   => g - 27 epoch -  464   => error -  0.021765856516337223  accuracy -  97.82341434836627
# Discrete CMAC:   => g - 27 epoch -  465   => error -  0.021758439914125627  accuracy -  97.82415600858744
# Discrete CMAC:   => g - 27 epoch -  466   => error -  0.02175108042114693  accuracy -  97.82489195788531
# Discrete CMAC:   => g - 27 epoch -  467   => error -  0.021743777555385813  accuracy -  97.82562224446141
# Discrete CMAC:   => g - 27 epoch -  468   => error -  0.021736530839295276  accuracy -  97.82634691607048
# Discrete CMAC:   => g - 27 epoch -  469   => error -  0.02172933979975067  accuracy -  97.82706602002493
# Discrete CMAC:   => g - 27 epoch -  470   => error -  0.021722203968003062  accuracy -  97.82777960319969
# Discrete CMAC:   => g - 27 epoch -  471   => error -  0.021715122879634285  accuracy -  97.82848771203658
# Discrete CMAC:   => g - 27 epoch -  472   => error -  0.02170809607451174  accuracy -  97.82919039254882
# Discrete CMAC:   => g - 27 epoch -  473   => error -  0.021701123096744324  accuracy -  97.82988769032556
# Discrete CMAC:   => g - 27 epoch -  474   => error -  0.021694203494638575  accuracy -  97.83057965053614
# Discrete CMAC:   => g - 27 epoch -  475   => error -  0.021687336820654934  accuracy -  97.8312663179345
# Discrete CMAC:   => g - 27 epoch -  476   => error -  0.021680522631365662  accuracy -  97.83194773686344
# Discrete CMAC:   => g - 27 epoch -  477   => error -  0.021673760487412097  accuracy -  97.8326239512588
# Discrete CMAC:   => g - 27 epoch -  478   => error -  0.021667049953462802  accuracy -  97.83329500465372
# Discrete CMAC:   => g - 27 epoch -  479   => error -  0.021660390598172485  accuracy -  97.83396094018275
# Discrete CMAC:   => g - 27 epoch -  480   => error -  0.021653781994141363  accuracy -  97.83462180058586
# Discrete CMAC:   => g - 27 epoch -  481   => error -  0.02164722371787453  accuracy -  97.83527762821255
# Discrete CMAC:   => g - 27 epoch -  482   => error -  0.02164071534974199  accuracy -  97.8359284650258
# Discrete CMAC:   => g - 27 epoch -  483   => error -  0.021634256473939795  accuracy -  97.83657435260602
# Discrete CMAC:   => g - 27 epoch -  484   => error -  0.021627846678450524  accuracy -  97.83721533215495
# Discrete CMAC:   => g - 27 epoch -  485   => error -  0.021621485555005315  accuracy -  97.83785144449946
# Discrete CMAC:   => g - 27 epoch -  486   => error -  0.02161517269904545  accuracy -  97.83848273009545
# Discrete CMAC:   => g - 27 epoch -  487   => error -  0.021608907709685266  accuracy -  97.83910922903148
# Discrete CMAC:   => g - 27 epoch -  488   => error -  0.021602690189674312  accuracy -  97.83973098103257
# Discrete CMAC:   => g - 27 epoch -  489   => error -  0.021596519745361253  accuracy -  97.84034802546387
# Discrete CMAC:   => g - 27 epoch -  490   => error -  0.02159039598665735  accuracy -  97.84096040133427
# Discrete CMAC:   => g - 27 epoch -  491   => error -  0.02158431852700049  accuracy -  97.84156814729995
# Discrete CMAC:   => g - 27 epoch -  492   => error -  0.021578286983319872  accuracy -  97.84217130166802
# Discrete CMAC:   => g - 27 epoch -  493   => error -  0.021572300976000935  accuracy -  97.84276990239991
# Discrete CMAC:   => g - 27 epoch -  494   => error -  0.021566360128850826  accuracy -  97.84336398711491
# Discrete CMAC:   => g - 27 epoch -  495   => error -  0.021560464069063867  accuracy -  97.84395359309362
# Discrete CMAC:   => g - 27 epoch -  496   => error -  0.021554612427187925  accuracy -  97.84453875728121
# Discrete CMAC:   => g - 27 epoch -  497   => error -  0.021548804837090874  accuracy -  97.84511951629091
# Discrete CMAC:   => g - 27 epoch -  498   => error -  0.021543040935927515  accuracy -  97.84569590640724
# Discrete CMAC:   => g - 27 epoch -  499   => error -  0.021537320364106938  accuracy -  97.84626796358931
# Discrete CMAC:   => g - 27 epoch -  500   => error -  0.021531642765260095  accuracy -  97.84683572347399
# Discrete CMAC:   => g - 27 epoch -  501   => error -  0.021526007786207724  accuracy -  97.84739922137923
# Discrete CMAC:   => g - 27 epoch -  502   => error -  0.021520415076929145  accuracy -  97.84795849230709
# Discrete CMAC:   => g - 27 epoch -  503   => error -  0.0215148642905304  accuracy -  97.84851357094696
# Discrete CMAC:   => g - 27 epoch -  504   => error -  0.021509355083214055  accuracy -  97.84906449167859
# Discrete CMAC:   => g - 27 epoch -  505   => error -  0.02150388711424811  accuracy -  97.84961128857519
# Discrete CMAC:   => g - 27 epoch -  506   => error -  0.021498460045935808  accuracy -  97.85015399540642
# Discrete CMAC:   => g - 27 epoch -  507   => error -  0.021493073543586316  accuracy -  97.85069264564137
# Discrete CMAC:   => g - 27 epoch -  508   => error -  0.021487727275484425  accuracy -  97.85122727245155
# Discrete CMAC:   => g - 27 epoch -  509   => error -  0.02148242091286201  accuracy -  97.8517579087138
# Discrete CMAC:   => g - 27 epoch -  510   => error -  0.021477154129868725  accuracy -  97.85228458701313
# Discrete CMAC:   => g - 27 epoch -  511   => error -  0.0214719266035438  accuracy -  97.85280733964562
# Discrete CMAC:   => g - 27 epoch -  512   => error -  0.0214667380137874  accuracy -  97.85332619862126
# Discrete CMAC:   => g - 27 epoch -  513   => error -  0.02146158804333287  accuracy -  97.85384119566672
# Discrete CMAC:   => g - 27 epoch -  514   => error -  0.021456476377719635  accuracy -  97.85435236222804
# Discrete CMAC:   => g - 27 epoch -  515   => error -  0.0214514027052648  accuracy -  97.85485972947352
# Discrete CMAC:   => g - 27 epoch -  516   => error -  0.021446366717037257  accuracy -  97.85536332829628
# Discrete CMAC:   => g - 27 epoch -  517   => error -  0.021441368106830172  accuracy -  97.85586318931698
# Discrete CMAC:   => g - 27 epoch -  518   => error -  0.021436406571135103  accuracy -  97.85635934288649
# Discrete CMAC:   => g - 27 epoch -  519   => error -  0.021431481809115693  accuracy -  97.85685181908843
# Discrete CMAC:   => g - 27 epoch -  520   => error -  0.021426593522581694  accuracy -  97.85734064774184
# Discrete CMAC:   => g - 27 epoch -  521   => error -  0.021421741415963647  accuracy -  97.85782585840363
# Discrete CMAC:   => g - 27 epoch -  522   => error -  0.02141692519628724  accuracy -  97.85830748037128
# Discrete CMAC:   => g - 27 epoch -  523   => error -  0.021412144573148995  accuracy -  97.8587855426851
# Discrete CMAC:   => g - 27 epoch -  524   => error -  0.02140739925869073  accuracy -  97.85926007413093
# Discrete CMAC:   => g - 27 epoch -  525   => error -  0.0214026889675758  accuracy -  97.85973110324242
# Discrete CMAC:   => g - 27 epoch -  526   => error -  0.021398013416964345  accuracy -  97.86019865830356
# Discrete CMAC:   => g - 27 epoch -  527   => error -  0.021393372326489746  accuracy -  97.86066276735103
# Discrete CMAC:   => g - 27 epoch -  528   => error -  0.02138876541823498  accuracy -  97.86112345817651
# Discrete CMAC:   => g - 27 epoch -  529   => error -  0.021384192416708747  accuracy -  97.86158075832913
# Discrete CMAC:   => g - 27 epoch -  530   => error -  0.021379653048822833  accuracy -  97.86203469511771
# Discrete CMAC:   => g - 27 epoch -  531   => error -  0.021375147043868892  accuracy -  97.86248529561311
# Discrete CMAC:   => g - 27 epoch -  532   => error -  0.021370674133495915  accuracy -  97.8629325866504
# Discrete CMAC:   => g - 27 epoch -  533   => error -  0.021366234051687805  accuracy -  97.86337659483122
# Discrete CMAC:   => g - 27 epoch -  534   => error -  0.021361826534741057  accuracy -  97.86381734652589
# Discrete CMAC:   => g - 27 epoch -  535   => error -  0.021357451321243004  accuracy -  97.8642548678757
# Discrete CMAC:   => g - 27 epoch -  536   => error -  0.02135310815205005  accuracy -  97.864689184795
# Discrete CMAC:   => g - 27 epoch -  537   => error -  0.02134879677026602  accuracy -  97.8651203229734
# Discrete CMAC:   => g - 27 epoch -  538   => error -  0.02134451692122119  accuracy -  97.86554830787789
# Discrete CMAC:   => g - 27 epoch -  539   => error -  0.021340268352451175  accuracy -  97.86597316475488
# Discrete CMAC:   => g - 27 epoch -  540   => error -  0.021336050813675733  accuracy -  97.86639491863242
# Discrete CMAC:   => g - 27 epoch -  541   => error -  0.021331864056778893  accuracy -  97.86681359432211
# Discrete CMAC:   => g - 27 epoch -  542   => error -  0.02132770783578819  accuracy -  97.86722921642118
# Discrete CMAC:   => g - 27 epoch -  543   => error -  0.02132358190685424  accuracy -  97.86764180931458
# Discrete CMAC:   => g - 27 epoch -  544   => error -  0.021319486028231527  accuracy -  97.86805139717684
# Discrete CMAC:   => g - 27 epoch -  545   => error -  0.021315419960258097  accuracy -  97.86845800397418
# Discrete CMAC:   => g - 27 epoch -  546   => error -  0.021311383465335898  accuracy -  97.86886165346641
# Discrete CMAC:   => g - 27 epoch -  547   => error -  0.02130737630791235  accuracy -  97.86926236920877
# Discrete CMAC:   => g - 27 epoch -  548   => error -  0.02130339825446015  accuracy -  97.86966017455399
# Discrete CMAC:   => g - 27 epoch -  549   => error -  0.021299449073459042  accuracy -  97.8700550926541
# Discrete CMAC:   => g - 27 epoch -  550   => error -  0.021295528535377084  accuracy -  97.8704471464623
# Discrete CMAC:   => g - 27 epoch -  551   => error -  0.02129163641265175  accuracy -  97.87083635873482
# Discrete CMAC:   => g - 27 epoch -  552   => error -  0.02128777247967184  accuracy -  97.87122275203282
# Discrete CMAC:   => g - 27 epoch -  553   => error -  0.021283936512759283  accuracy -  97.87160634872407
# Discrete CMAC:   => g - 27 epoch -  554   => error -  0.021280128290151357  accuracy -  97.87198717098487
# Discrete CMAC:   => g - 27 epoch -  555   => error -  0.021276347591982603  accuracy -  97.87236524080174
# Discrete CMAC:   => g - 27 epoch -  556   => error -  0.021272594200267503  accuracy -  97.87274057997325
# Discrete CMAC:   => g - 27 epoch -  557   => error -  0.021268867898883048  accuracy -  97.8731132101117
# Discrete CMAC:   => g - 27 epoch -  558   => error -  0.02126516847355131  accuracy -  97.87348315264487
# Discrete CMAC:   => g - 27 epoch -  559   => error -  0.021261495711822676  accuracy -  97.87385042881773
# Discrete CMAC:   => g - 27 epoch -  560   => error -  0.02125784940305886  accuracy -  97.87421505969411
# Discrete CMAC:   => g - 27 epoch -  561   => error -  0.021254229338416253  accuracy -  97.87457706615838
# Discrete CMAC:   => g - 27 epoch -  562   => error -  0.021250635310828936  accuracy -  97.87493646891711
# Discrete CMAC:   => g - 27 epoch -  563   => error -  0.021247067114993357  accuracy -  97.87529328850067
# Discrete CMAC:   => g - 27 epoch -  564   => error -  0.02124352454735101  accuracy -  97.8756475452649
# Discrete CMAC:   => g - 27 epoch -  565   => error -  0.021240007406073014  accuracy -  97.8759992593927
# Discrete CMAC:   => g - 27 epoch -  566   => error -  0.02123651549104444  accuracy -  97.87634845089556
# Discrete CMAC:   => g - 27 epoch -  567   => error -  0.021233048603847893  accuracy -  97.87669513961521
# Discrete CMAC:   => g - 27 epoch -  568   => error -  0.021229606547748636  accuracy -  97.87703934522514
# Discrete CMAC:   => g - 27 epoch -  569   => error -  0.02122618912767904  accuracy -  97.8773810872321
# Discrete CMAC:   => g - 27 epoch -  570   => error -  0.021222796150222933  accuracy -  97.8777203849777
# Discrete CMAC:   => g - 27 epoch -  571   => error -  0.021219427423601167  accuracy -  97.87805725763988
# Discrete CMAC:   => g - 27 epoch -  572   => error -  0.021216082757656296  accuracy -  97.87839172423438
# Discrete CMAC:   => g - 27 epoch -  573   => error -  0.021212761963837812  accuracy -  97.87872380361623
# Discrete CMAC:   => g - 27 epoch -  574   => error -  0.02120946485518782  accuracy -  97.87905351448121
# Discrete CMAC:   => g - 27 epoch -  575   => error -  0.021206191246326056  accuracy -  97.87938087536739
# Discrete CMAC:   => g - 27 epoch -  576   => error -  0.021202940953436  accuracy -  97.8797059046564
# Discrete CMAC:   => g - 27 epoch -  577   => error -  0.021199713794250563  accuracy -  97.88002862057495
# Discrete CMAC:   => g - 27 epoch -  578   => error -  0.02119650958803798  accuracy -  97.8803490411962
# Discrete CMAC:   => g - 27 epoch -  579   => error -  0.02119332815558761  accuracy -  97.88066718444124
# Discrete CMAC:   => g - 27 epoch -  580   => error -  0.021190169319196928  accuracy -  97.88098306808031
# Discrete CMAC:   => g - 27 epoch -  581   => error -  0.02118703290265722  accuracy -  97.88129670973427
# Discrete CMAC:   => g - 27 epoch -  582   => error -  0.021183918731240148  accuracy -  97.88160812687599
# Discrete CMAC:   => g - 27 epoch -  583   => error -  0.021180826631684857  accuracy -  97.88191733683152
# Discrete CMAC:   => g - 27 epoch -  584   => error -  0.021177756432184225  accuracy -  97.88222435678158
# Discrete CMAC:   => g - 27 epoch -  585   => error -  0.021174707962371975  accuracy -  97.8825292037628
# Discrete CMAC:   => g - 27 epoch -  586   => error -  0.021171681053309577  accuracy -  97.88283189466904
# Discrete CMAC:   => g - 27 epoch -  587   => error -  0.021168675537473813  accuracy -  97.88313244625262
# Discrete CMAC:   => g - 27 epoch -  588   => error -  0.021165691248743568  accuracy -  97.88343087512564
# Discrete CMAC:   => g - 27 epoch -  589   => error -  0.021162728022387278  accuracy -  97.88372719776127
# Discrete CMAC:   => g - 27 epoch -  590   => error -  0.021159785695050837  accuracy -  97.88402143049491
# Discrete CMAC:   => g - 27 epoch -  591   => error -  0.021156864104745043  accuracy -  97.88431358952549
# Discrete CMAC:   => g - 27 epoch -  592   => error -  0.021153963090833172  accuracy -  97.88460369091668
# Discrete CMAC:   => g - 27 epoch -  593   => error -  0.02115108249401909  accuracy -  97.88489175059809
# Discrete CMAC:   => g - 27 epoch -  594   => error -  0.021148222156335383  accuracy -  97.88517778436646
# Discrete CMAC:   => g - 27 epoch -  595   => error -  0.021145381921131134  accuracy -  97.88546180788688
# Discrete CMAC:   => g - 27 epoch -  596   => error -  0.021142561633060497  accuracy -  97.88574383669395
# Discrete CMAC:   => g - 27 epoch -  597   => error -  0.021139761138070923  accuracy -  97.8860238861929
# Discrete CMAC:   => g - 27 epoch -  598   => error -  0.021136980283391504  accuracy -  97.88630197166086
# Discrete CMAC:   => g - 27 epoch -  599   => error -  0.021134218917521652  accuracy -  97.88657810824783
# Discrete CMAC:   => g - 27 epoch -  600   => error -  0.021131476890220102  accuracy -  97.88685231097799
# Discrete CMAC:   => g - 27 epoch -  601   => error -  0.02112875405249326  accuracy -  97.88712459475067
# Discrete CMAC:   => g - 27 epoch -  602   => error -  0.021126050256584095  accuracy -  97.88739497434159
# Discrete CMAC:   => g - 27 epoch -  603   => error -  0.02112336535596171  accuracy -  97.88766346440383
# Discrete CMAC:   => g - 27 epoch -  604   => error -  0.0211206992053099  accuracy -  97.88793007946902
# Discrete CMAC:   => g - 27 epoch -  605   => error -  0.021118051660516723  accuracy -  97.88819483394833
# Discrete CMAC:   => g - 27 epoch -  606   => error -  0.0211154225786635  accuracy -  97.88845774213365
# Discrete CMAC:   => g - 27 epoch -  607   => error -  0.02111281181801461  accuracy -  97.88871881819854
# Discrete CMAC:   => g - 27 epoch -  608   => error -  0.021110219238006933  accuracy -  97.88897807619931
# Discrete CMAC:   => g - 27 epoch -  609   => error -  0.021107644699239203  accuracy -  97.88923553007608
# Discrete CMAC:   => g - 27 epoch -  610   => error -  0.02110508806346212  accuracy -  97.88949119365378
# Discrete CMAC:   => g - 27 epoch -  611   => error -  0.021102549193568132  accuracy -  97.88974508064318
# Discrete CMAC:   => g - 27 epoch -  612   => error -  0.021100027953581013  accuracy -  97.8899972046419
# Discrete CMAC:   => g - 27 epoch -  613   => error -  0.0210975242086463  accuracy -  97.89024757913538
# Discrete CMAC:   => g - 27 epoch -  614   => error -  0.021095037825021312  accuracy -  97.89049621749787
# Discrete CMAC:   => g - 27 epoch -  615   => error -  0.021092568670065037  accuracy -  97.89074313299349
# Discrete CMAC:   => g - 27 epoch -  616   => error -  0.02109011661222915  accuracy -  97.89098833877709
# Discrete CMAC:   => g - 27 epoch -  617   => error -  0.021087681521047674  accuracy -  97.89123184789523
# Discrete CMAC:   => g - 27 epoch -  618   => error -  0.021085263267127674  accuracy -  97.89147367328724
# Discrete CMAC:   => g - 27 epoch -  619   => error -  0.021082861722140467  accuracy -  97.89171382778595
# Discrete CMAC:   => g - 27 epoch -  620   => error -  0.021080476758811084  accuracy -  97.89195232411889
# Discrete CMAC:   => g - 27 epoch -  621   => error -  0.021078108250910388  accuracy -  97.89218917490896
# Discrete CMAC:   => g - 27 epoch -  622   => error -  0.021075756073244856  accuracy -  97.89242439267551
# Discrete CMAC:   => g - 27 epoch -  623   => error -  0.02107342010164781  accuracy -  97.89265798983521
# Discrete CMAC:   => g - 27 epoch -  624   => error -  0.021071100212970983  accuracy -  97.8928899787029
# Discrete CMAC:   => g - 27 epoch -  625   => error -  0.021068796285074853  accuracy -  97.89312037149251
# Discrete CMAC:   => g - 27 epoch -  626   => error -  0.02106650819682021  accuracy -  97.89334918031798
# Discrete CMAC:   => g - 27 epoch -  627   => error -  0.021064235828059386  accuracy -  97.89357641719405
# Discrete CMAC:   => g - 27 epoch -  628   => error -  0.021061979059627478  accuracy -  97.89380209403726
# Discrete CMAC:   => g - 27 epoch -  629   => error -  0.021059737773334253  accuracy -  97.89402622266657
# Discrete CMAC:   => g - 27 epoch -  630   => error -  0.021057511851954924  accuracy -  97.89424881480451
# Discrete CMAC:   => g - 27 epoch -  631   => error -  0.021055301179222274  accuracy -  97.89446988207777
# Discrete CMAC:   => g - 27 epoch -  632   => error -  0.021053105639818104  accuracy -  97.89468943601818
# Discrete CMAC:   => g - 27 epoch -  633   => error -  0.021050925119365127  accuracy -  97.89490748806348
# Discrete CMAC:   => g - 27 epoch -  634   => error -  0.021048759504418868  accuracy -  97.89512404955812
# Discrete CMAC:   => g - 27 epoch -  635   => error -  0.021046608682459  accuracy -  97.8953391317541
# Discrete CMAC:   => g - 27 epoch -  636   => error -  0.02104447254188213  accuracy -  97.89555274581178
# Discrete CMAC:   => g - 27 epoch -  637   => error -  0.021042350971993362  accuracy -  97.89576490280066
# Discrete CMAC:   => g - 27 epoch -  638   => error -  0.021040243862998298  accuracy -  97.89597561370017
# Discrete CMAC:   => g - 27 epoch -  639   => error -  0.021038151105995828  accuracy -  97.89618488940042
# Discrete CMAC:   => g - 27 epoch -  640   => error -  0.02103607259296969  accuracy -  97.89639274070304
# Discrete CMAC:   => g - 27 epoch -  641   => error -  0.021034008216781364  accuracy -  97.89659917832186
# Discrete CMAC:   => g - 27 epoch -  642   => error -  0.021031957871162188  accuracy -  97.89680421288378
# Discrete CMAC:   => g - 27 epoch -  643   => error -  0.021029921450706035  accuracy -  97.8970078549294
# Discrete CMAC:   => g - 27 epoch -  644   => error -  0.021027898850861537  accuracy -  97.89721011491385
# Discrete CMAC:   => g - 27 epoch -  645   => error -  0.021025889967925204  accuracy -  97.89741100320748
# Discrete CMAC:   => g - 27 epoch -  646   => error -  0.02102389469903365  accuracy -  97.89761053009663
# Discrete CMAC:   => g - 27 epoch -  647   => error -  0.021021912942156606  accuracy -  97.89780870578434
# Discrete CMAC:   => g - 27 epoch -  648   => error -  0.02101994459608958  accuracy -  97.89800554039104
# Discrete CMAC:   => g - 27 epoch -  649   => error -  0.021017989560447092  accuracy -  97.8982010439553
# Discrete CMAC:   => g - 27 epoch -  650   => error -  0.02101604773565502  accuracy -  97.8983952264345
# Discrete CMAC:   => g - 27 epoch -  651   => error -  0.021014119022944366  accuracy -  97.89858809770557
# Discrete CMAC:   => g - 27 epoch -  652   => error -  0.021012203324343615  accuracy -  97.89877966756563
# Discrete CMAC:   => g - 27 epoch -  653   => error -  0.02101030054267239  accuracy -  97.89896994573276
# Discrete CMAC:   => g - 27 epoch -  654   => error -  0.021008410581534576  accuracy -  97.89915894184654
# Discrete CMAC:   => g - 27 epoch -  655   => error -  0.021006533345311218  accuracy -  97.89934666546888
# Discrete CMAC:   => g - 27 epoch -  656   => error -  0.02100466873915452  accuracy -  97.89953312608455
# Discrete CMAC:   => g - 27 epoch -  657   => error -  0.021002816668980406  accuracy -  97.89971833310196
# Discrete CMAC:   => g - 27 epoch -  658   => error -  0.021000977041462976  accuracy -  97.8999022958537
# Discrete CMAC:   => g - 27 epoch -  659   => error -  0.020999149764026948  accuracy -  97.9000850235973
# Discrete CMAC:   => g - 27 epoch -  660   => error -  0.020997334744842  accuracy -  97.9002665255158
# Discrete CMAC:   => g - 27 epoch -  661   => error -  0.020995531892816333  accuracy -  97.90044681071836
# Discrete CMAC:   => g - 27 epoch -  662   => error -  0.02099374111758978  accuracy -  97.90062588824102
# Discrete CMAC:   => g - 27 epoch -  663   => error -  0.02099196232952838  accuracy -  97.90080376704717
# Discrete CMAC:   => g - 27 epoch -  664   => error -  0.020990195439717363  accuracy -  97.90098045602826
# Discrete CMAC:   => g - 27 epoch -  665   => error -  0.020988440359955618  accuracy -  97.90115596400443
# Discrete CMAC:   => g - 27 epoch -  666   => error -  0.020986697002749466  accuracy -  97.90133029972506
# Discrete CMAC:   => g - 27 epoch -  667   => error -  0.020984965281306445  accuracy -  97.90150347186936
# Discrete CMAC:   => g - 27 epoch -  668   => error -  0.020983245109529314  accuracy -  97.90167548904707
# Discrete CMAC:   => g - 27 epoch -  669   => error -  0.020981536402010614  accuracy -  97.90184635979894
# Discrete CMAC:   => g - 27 epoch -  670   => error -  0.02097983907402623  accuracy -  97.90201609259738
# Discrete CMAC:   => g - 27 epoch -  671   => error -  0.020978153041529612  accuracy -  97.90218469584704
# Discrete CMAC:   => g - 27 epoch -  672   => error -  0.020976478221146677  accuracy -  97.90235217788533
# Discrete CMAC:   => g - 27 epoch -  673   => error -  0.02097481453016914  accuracy -  97.90251854698309
# Discrete CMAC:   => g - 27 epoch -  674   => error -  0.02097316188654963  accuracy -  97.90268381134504
# Discrete CMAC:   => g - 27 epoch -  675   => error -  0.02097152020889581  accuracy -  97.90284797911042
# Discrete CMAC:   => g - 27 epoch -  676   => error -  0.020969889416464493  accuracy -  97.90301105835356
# Discrete CMAC:   => g - 27 epoch -  677   => error -  0.02096826942915686  accuracy -  97.90317305708432
# Discrete CMAC:   => g - 27 epoch -  678   => error -  0.02096666016751214  accuracy -  97.90333398324879
# Discrete CMAC:   => g - 27 epoch -  679   => error -  0.020965061552702946  accuracy -  97.90349384472971
# Discrete CMAC:   => g - 27 epoch -  680   => error -  0.020963473506529495  accuracy -  97.90365264934705
# Discrete CMAC:   => g - 27 epoch -  681   => error -  0.0209618959514144  accuracy -  97.90381040485856
# Discrete CMAC:   => g - 27 epoch -  682   => error -  0.020960328810397666  accuracy -  97.90396711896024
# Discrete CMAC:   => g - 27 epoch -  683   => error -  0.0209587720071307  accuracy -  97.90412279928692
# Discrete CMAC:   => g - 27 epoch -  684   => error -  0.020957225465872087  accuracy -  97.90427745341279
# Discrete CMAC:   => g - 27 epoch -  685   => error -  0.020955689111481934  accuracy -  97.90443108885181
# Discrete CMAC:   => g - 27 epoch -  686   => error -  0.02095416286941676  accuracy -  97.90458371305833
# Discrete CMAC:   => g - 27 epoch -  687   => error -  0.020952646665724828  accuracy -  97.90473533342751
# Discrete CMAC:   => g - 27 epoch -  688   => error -  0.020951140427040715  accuracy -  97.90488595729593
# Discrete CMAC:   => g - 27 epoch -  689   => error -  0.020949644080580643  accuracy -  97.90503559194194
# Discrete CMAC:   => g - 27 epoch -  690   => error -  0.020948157554137592  accuracy -  97.90518424458624
# Discrete CMAC:   => g - 27 epoch -  691   => error -  0.0209466807760762  accuracy -  97.90533192239238
# Discrete CMAC:   => g - 27 epoch -  692   => error -  0.0209452136753282  accuracy -  97.90547863246718
# Discrete CMAC:   => g - 27 epoch -  693   => error -  0.02094375618138755  accuracy -  97.90562438186124
# Discrete CMAC:   => g - 27 epoch -  694   => error -  0.02094230822430576  accuracy -  97.90576917756943
# Discrete CMAC:   => g - 27 epoch -  695   => error -  0.02094086973468723  accuracy -  97.90591302653128
# Discrete CMAC:   => g - 27 epoch -  696   => error -  0.020939440643684137  accuracy -  97.90605593563158
# Discrete CMAC:   => g - 27 epoch -  697   => error -  0.02093802088299268  accuracy -  97.90619791170073
# Discrete CMAC:   => g - 27 epoch -  698   => error -  0.020936610384847953  accuracy -  97.9063389615152
# Discrete CMAC:   => g - 27 epoch -  699   => error -  0.02093520908201929  accuracy -  97.90647909179808
# Discrete CMAC:   => g - 27 epoch -  700   => error -  0.02093381690780627  accuracy -  97.90661830921937
# Discrete CMAC:   => g - 27 epoch -  701   => error -  0.020932433796034045  accuracy -  97.90675662039659
# Discrete CMAC:   => g - 27 epoch -  702   => error -  0.02093105968104869  accuracy -  97.90689403189513
# Discrete CMAC:   => g - 27 epoch -  703   => error -  0.020929694497713314  accuracy -  97.90703055022867
# Discrete CMAC:   => g - 27 epoch -  704   => error -  0.020928338181403383  accuracy -  97.90716618185967
# Discrete CMAC:   => g - 27 epoch -  705   => error -  0.02092699066800252  accuracy -  97.90730093319975
# Discrete CMAC:   => g - 27 epoch -  706   => error -  0.020925651893898167  accuracy -  97.90743481061018
# Discrete CMAC:   => g - 27 epoch -  707   => error -  0.020924321795977807  accuracy -  97.90756782040222
# Discrete CMAC:   => g - 27 epoch -  708   => error -  0.020923000311624085  accuracy -  97.90769996883759
# Discrete CMAC:   => g - 27 epoch -  709   => error -  0.02092168737871114  accuracy -  97.90783126212888
# Discrete CMAC:   => g - 27 epoch -  710   => error -  0.020920382935600612  accuracy -  97.90796170643993
# Discrete CMAC:   => g - 27 epoch -  711   => error -  0.020919086921137198  accuracy -  97.90809130788628
# Discrete CMAC:   => g - 27 epoch -  712   => error -  0.020917799274644655  accuracy -  97.90822007253553
# Discrete CMAC:   => g - 27 epoch -  713   => error -  0.02091651993592225  accuracy -  97.90834800640778
# Discrete CMAC:   => g - 27 epoch -  714   => error -  0.020915248845240098  accuracy -  97.908475115476
# Discrete CMAC:   => g - 27 epoch -  715   => error -  0.020913985943336044  accuracy -  97.90860140566639
# Discrete CMAC:   => g - 27 epoch -  716   => error -  0.020912731171411125  accuracy -  97.90872688285889
# Discrete CMAC:   => g - 27 epoch -  717   => error -  0.020911484471125896  accuracy -  97.90885155288741
# Discrete CMAC:   => g - 27 epoch -  718   => error -  0.02091024578459677  accuracy -  97.90897542154032
# Discrete CMAC:   => g - 27 epoch -  719   => error -  0.02090901505439202  accuracy -  97.9090984945608
# Discrete CMAC:   => g - 27 epoch -  720   => error -  0.02090779222352812  accuracy -  97.90922077764719
# Discrete CMAC:   => g - 27 epoch -  721   => error -  0.020906577235466184  accuracy -  97.90934227645339
# Discrete CMAC:   => g - 27 epoch -  722   => error -  0.02090537003410775  accuracy -  97.90946299658923
# Discrete CMAC:   => g - 27 epoch -  723   => error -  0.020904170563791902  accuracy -  97.9095829436208
# Discrete CMAC:   => g - 27 epoch -  724   => error -  0.020902978769290925  accuracy -  97.9097021230709
# Discrete CMAC:   => g - 27 epoch -  725   => error -  0.02090179459580699  accuracy -  97.9098205404193
# Discrete CMAC:   => g - 27 epoch -  726   => error -  0.020900617988968695  accuracy -  97.90993820110313
# Discrete CMAC:   => g - 27 epoch -  727   => error -  0.020899448894827533  accuracy -  97.91005511051725
# Discrete CMAC:   => g - 27 epoch -  728   => error -  0.020898287259853987  accuracy -  97.9101712740146
# Discrete CMAC:   => g - 27 epoch -  729   => error -  0.020897133030934767  accuracy -  97.91028669690652
# Discrete CMAC:   => g - 27 epoch -  730   => error -  0.020895986155368695  accuracy -  97.91040138446313
# Discrete CMAC:   => g - 27 epoch -  731   => error -  0.02089484658086349  accuracy -  97.91051534191365
# Discrete CMAC:   => g - 27 epoch -  732   => error -  0.02089371425553277  accuracy -  97.91062857444672
# Discrete CMAC:   => g - 27 epoch -  733   => error -  0.020892589127892047  accuracy -  97.9107410872108
# Discrete CMAC:   => g - 27 epoch -  734   => error -  0.020891471146855967  accuracy -  97.9108528853144
# Discrete CMAC:   => g - 27 epoch -  735   => error -  0.02089036026173474  accuracy -  97.91096397382653
# Discrete CMAC:   => g - 27 epoch -  736   => error -  0.02088925642223094  accuracy -  97.91107435777691
# Discrete CMAC:   => g - 27 epoch -  737   => error -  0.02088815957843615  accuracy -  97.91118404215638
# Discrete CMAC:   => g - 27 epoch -  738   => error -  0.020887069680827985  accuracy -  97.9112930319172
# Discrete CMAC:   => g - 27 epoch -  739   => error -  0.020885986680266866  accuracy -  97.91140133197331
# Discrete CMAC:   => g - 27 epoch -  740   => error -  0.02088491052799235  accuracy -  97.91150894720076
# Discrete CMAC:   => g - 27 epoch -  741   => error -  0.020883841175621032  accuracy -  97.9116158824379
# Discrete CMAC:   => g - 27 epoch -  742   => error -  0.020882778575142313  accuracy -  97.91172214248577
# Discrete CMAC:   => g - 27 epoch -  743   => error -  0.020881722678916304  accuracy -  97.91182773210836
# Discrete CMAC:   => g - 27 epoch -  744   => error -  0.020880673439669928  accuracy -  97.911932656033
# Discrete CMAC:   => g - 27 epoch -  745   => error -  0.02087963081049471  accuracy -  97.91203691895053
# Discrete CMAC:   => g - 27 epoch -  746   => error -  0.020878594744843104  accuracy -  97.9121405255157
# Discrete CMAC:   => g - 27 epoch -  747   => error -  0.020877565196525838  accuracy -  97.91224348034741
# Discrete CMAC:   => g - 27 epoch -  748   => error -  0.02087654211970902  accuracy -  97.9123457880291
# Discrete CMAC:   => g - 27 epoch -  749   => error -  0.020875525468911027  accuracy -  97.9124474531089
# Discrete CMAC:   => g - 27 epoch -  750   => error -  0.020874515198999966  accuracy -  97.9125484801
# Discrete CMAC:   => g - 27 epoch -  751   => error -  0.020873511265190325  accuracy -  97.91264887348096
# Discrete CMAC:   => g - 27 epoch -  752   => error -  0.020872513623040323  accuracy -  97.91274863769597
# Discrete CMAC:   => g - 27 epoch -  753   => error -  0.020871522228449457  accuracy -  97.91284777715505
# Discrete CMAC:   => g - 27 epoch -  754   => error -  0.020870537037654957  accuracy -  97.91294629623451
# Discrete CMAC:   => g - 27 epoch -  755   => error -  0.020869558007229894  accuracy -  97.91304419927701
# Discrete CMAC:   => g - 27 epoch -  756   => error -  0.020868585094079628  accuracy -  97.91314149059204
# Discrete CMAC:   => g - 27 epoch -  757   => error -  0.0208676182554397  accuracy -  97.91323817445603
# Discrete CMAC:   => g - 27 epoch -  758   => error -  0.020866657448872727  accuracy -  97.91333425511273
# Discrete CMAC:   => g - 27 epoch -  759   => error -  0.020865702632265948  accuracy -  97.91342973677341
# Discrete CMAC:   => g - 27 epoch -  760   => error -  0.02086475376382846  accuracy -  97.91352462361715
# Discrete CMAC:   => g - 27 epoch -  761   => error -  0.020863810802088656  accuracy -  97.91361891979113
# Discrete CMAC:   => g - 27 epoch -  762   => error -  0.020862873705891682  accuracy -  97.91371262941084
# Discrete CMAC:   => g - 27 epoch -  763   => error -  0.02086194243439654  accuracy -  97.91380575656035
# Discrete CMAC:   => g - 27 epoch -  764   => error -  0.020861016947073985  accuracy -  97.9138983052926
# Discrete CMAC:   => g - 27 epoch -  765   => error -  0.02086009720370363  accuracy -  97.91399027962964
# Discrete CMAC:   => g - 27 epoch -  766   => error -  0.02085918316437163  accuracy -  97.91408168356284
# Discrete CMAC:   => g - 27 epoch -  767   => error -  0.02085827478946789  accuracy -  97.91417252105322
# Discrete CMAC:   => g - 27 epoch -  768   => error -  0.020857372039684074  accuracy -  97.9142627960316
# Discrete CMAC:   => g - 27 epoch -  769   => error -  0.020856474876010722  accuracy -  97.91435251239892
# Discrete CMAC:   => g - 27 epoch -  770   => error -  0.020855583259735022  accuracy -  97.91444167402649
# Discrete CMAC:   => g - 27 epoch -  771   => error -  0.020854697152438262  accuracy -  97.91453028475617
# Discrete CMAC:   => g - 27 epoch -  772   => error -  0.020853816515993495  accuracy -  97.91461834840065
# Discrete CMAC:   => g - 27 epoch -  773   => error -  0.020852941312563433  accuracy -  97.91470586874365
# Discrete CMAC:   => g - 27 epoch -  774   => error -  0.02085207150459767  accuracy -  97.91479284954023
# Discrete CMAC:   => g - 27 epoch -  775   => error -  0.020851207054830456  accuracy -  97.91487929451695
# Discrete CMAC:   => g - 27 epoch -  776   => error -  0.02085034792627871  accuracy -  97.91496520737213
# Discrete CMAC:   => g - 27 epoch -  777   => error -  0.02084949408223924  accuracy -  97.91505059177608
# Discrete CMAC:   => g - 27 epoch -  778   => error -  0.020848645486286732  accuracy -  97.91513545137133
# Discrete CMAC:   => g - 27 epoch -  779   => error -  0.020847802102271773  accuracy -  97.91521978977282
# Discrete CMAC:   => g - 27 epoch -  780   => error -  0.020846963894317838  accuracy -  97.91530361056822
# Discrete CMAC:   => g - 27 epoch -  781   => error -  0.020846130826820075  accuracy -  97.91538691731799
# Discrete CMAC:   => g - 27 epoch -  782   => error -  0.020845302864442194  accuracy -  97.91546971355578
# Discrete CMAC:   => g - 27 epoch -  783   => error -  0.020844479972114915  accuracy -  97.9155520027885
# Discrete CMAC:   => g - 27 epoch -  784   => error -  0.020843662115033412  accuracy -  97.91563378849666
# Discrete CMAC:   => g - 27 epoch -  785   => error -  0.020842849258655538  accuracy -  97.91571507413444
# Discrete CMAC:   => g - 27 epoch -  786   => error -  0.02084204136869927  accuracy -  97.91579586313007
# Discrete CMAC:   => g - 27 epoch -  787   => error -  0.02084123841114116  accuracy -  97.91587615888588
# Discrete CMAC:   => g - 27 epoch -  788   => error -  0.02084044035221355  accuracy -  97.91595596477865
# Discrete CMAC:   => g - 27 epoch -  789   => error -  0.02083964715840314  accuracy -  97.91603528415969
# Discrete CMAC:   => g - 27 epoch -  790   => error -  0.020838858796448756  accuracy -  97.91611412035512
# Discrete CMAC:   => g - 27 epoch -  791   => error -  0.020838075233338915  accuracy -  97.91619247666611
# Discrete CMAC:   => g - 27 epoch -  792   => error -  0.020837296436310382  accuracy -  97.91627035636895
# Discrete CMAC:   => g - 27 epoch -  793   => error -  0.020836522372845945  accuracy -  97.9163477627154
# Discrete CMAC:   => g - 27 epoch -  794   => error -  0.020835753010672198  accuracy -  97.91642469893279
# Discrete CMAC:   => g - 27 epoch -  795   => error -  0.020834988317758096  accuracy -  97.91650116822419
# Discrete CMAC:   => g - 27 epoch -  796   => error -  0.020834228262312404  accuracy -  97.91657717376876
# Discrete CMAC:   => g - 27 epoch -  797   => error -  0.02083347281278225  accuracy -  97.91665271872178
# Discrete CMAC:   => g - 27 epoch -  798   => error -  0.020832721937850796  accuracy -  97.91672780621492
# Discrete CMAC:   => g - 27 epoch -  799   => error -  0.020831975606435904  accuracy -  97.91680243935642
# Discrete CMAC:   => g - 27 epoch -  800   => error -  0.020831233787687697  accuracy -  97.91687662123122
# Discrete CMAC:   => g - 27 epoch -  801   => error -  0.02083049645098689  accuracy -  97.91695035490132
# Discrete CMAC:   => g - 27 epoch -  802   => error -  0.020829763565942905  accuracy -  97.91702364340571
# Discrete CMAC:   => g - 27 epoch -  803   => error -  0.020829035102392313  accuracy -  97.91709648976077
# Discrete CMAC:   => g - 27 epoch -  804   => error -  0.020828311030396396  accuracy -  97.91716889696036
# Discrete CMAC:   => g - 27 epoch -  805   => error -  0.020827591320240257  accuracy -  97.91724086797598
# Discrete CMAC:   => g - 27 epoch -  806   => error -  0.020826875942430045  accuracy -  97.917312405757
# Discrete CMAC:   => g - 27 epoch -  807   => error -  0.020826164867691732  accuracy -  97.91738351323083
# Discrete CMAC:   => g - 27 epoch -  808   => error -  0.020825458066969338  accuracy -  97.91745419330307
# Discrete CMAC:   => g - 27 epoch -  809   => error -  0.020824755511423154  accuracy -  97.91752444885769
# Discrete CMAC:   => g - 27 epoch -  810   => error -  0.020824057172427857  accuracy -  97.91759428275722
# Discrete CMAC:   => g - 27 epoch -  811   => error -  0.02082336302157084  accuracy -  97.91766369784291
# Discrete CMAC:   => g - 27 epoch -  812   => error -  0.020822673030650773  accuracy -  97.91773269693492
# Discrete CMAC:   => g - 27 epoch -  813   => error -  0.020821987171675382  accuracy -  97.91780128283246
# Discrete CMAC:   => g - 27 epoch -  814   => error -  0.020821305416860558  accuracy -  97.91786945831394
# Discrete CMAC:   => g - 27 epoch -  815   => error -  0.020820627738627806  accuracy -  97.91793722613721
# Discrete CMAC:   => g - 27 epoch -  816   => error -  0.020819954109603245  accuracy -  97.91800458903967
# Discrete CMAC:   => g - 27 epoch -  817   => error -  0.02081928450261572  accuracy -  97.91807154973843
# Discrete CMAC:   => g - 27 epoch -  818   => error -  0.020818618890695362  accuracy -  97.91813811093047
# Discrete CMAC:   => g - 27 epoch -  819   => error -  0.020817957247071583  accuracy -  97.91820427529284
# Discrete CMAC:   => g - 27 epoch -  820   => error -  0.020817299545172085  accuracy -  97.91827004548279
# Discrete CMAC:   => g - 27 epoch -  821   => error -  0.020816645758620633  accuracy -  97.91833542413794
# Discrete CMAC:   => g - 27 epoch -  822   => error -  0.02081599586123617  accuracy -  97.91840041387638
# Discrete CMAC:   => g - 27 epoch -  823   => error -  0.020815349827030483  accuracy -  97.91846501729695
# Discrete CMAC:   => g - 27 epoch -  824   => error -  0.02081470763020743  accuracy -  97.91852923697925
# Discrete CMAC:   => g - 27 epoch -  825   => error -  0.02081406924516105  accuracy -  97.9185930754839
# Discrete CMAC:   => g - 27 epoch -  826   => error -  0.020813434646473894  accuracy -  97.91865653535261
# Discrete CMAC:   => g - 27 epoch -  827   => error -  0.020812803808915814  accuracy -  97.91871961910842
# Discrete CMAC:   => g - 27 epoch -  828   => error -  0.020812176707442287  accuracy -  97.91878232925578
# Discrete CMAC:   => g - 27 epoch -  829   => error -  0.02081155331719331  accuracy -  97.91884466828067
# Discrete CMAC:   => g - 27 epoch -  830   => error -  0.0208109336134914  accuracy -  97.91890663865087
# Discrete CMAC:   => g - 27 epoch -  831   => error -  0.020810317571840264  accuracy -  97.91896824281598
# Discrete CMAC:   => g - 27 epoch -  832   => error -  0.02080970516792391  accuracy -  97.91902948320761
# Discrete CMAC:   => g - 27 epoch -  833   => error -  0.02080909637760442  accuracy -  97.91909036223956
# Discrete CMAC:   => g - 27 epoch -  834   => error -  0.020808491176921184  accuracy -  97.91915088230787
# Discrete CMAC:   => g - 27 epoch -  835   => error -  0.02080788954208901  accuracy -  97.9192110457911
# Discrete CMAC:   => g - 27 epoch -  836   => error -  0.020807291449497223  accuracy -  97.91927085505027
# Discrete CMAC:   => g - 27 epoch -  837   => error -  0.020806696875707797  accuracy -  97.91933031242922
# Discrete CMAC:   => g - 27 epoch -  838   => error -  0.020806105797454344  accuracy -  97.91938942025456
# Discrete CMAC:   => g - 27 epoch -  839   => error -  0.02080551819164045  accuracy -  97.91944818083596
# Discrete CMAC:   => g - 27 epoch -  840   => error -  0.020804934035338896  accuracy -  97.9195065964661
# Discrete CMAC:   => g - 27 epoch -  841   => error -  0.020804353305789447  accuracy -  97.91956466942105
# Discrete CMAC:   => g - 27 epoch -  842   => error -  0.020803775980398398  accuracy -  97.91962240196015
# Discrete CMAC:   => g - 27 epoch -  843   => error -  0.0208032020367368  accuracy -  97.91967979632632
# Discrete CMAC:   => g - 27 epoch -  844   => error -  0.020802631452539022  accuracy -  97.91973685474609
# Discrete CMAC:   => g - 27 epoch -  845   => error -  0.020802064205701964  accuracy -  97.91979357942981
# Discrete CMAC:   => g - 27 epoch -  846   => error -  0.020801500274283402  accuracy -  97.91984997257165
# Discrete CMAC:   => g - 27 epoch -  847   => error -  0.02080093963650076  accuracy -  97.91990603634993
# Discrete CMAC:   => g - 27 epoch -  848   => error -  0.02080038227073  accuracy -  97.919961772927
# Discrete CMAC:   => g - 27 epoch -  849   => error -  0.020799828155504296  accuracy -  97.92001718444958
# Discrete CMAC:   => g - 27 epoch -  850   => error -  0.020799277269512695  accuracy -  97.92007227304873
# Discrete CMAC:   => g - 27 epoch -  851   => error -  0.02079872959159912  accuracy -  97.92012704084009
# Discrete CMAC:   => g - 27 epoch -  852   => error -  0.020798185100760813  accuracy -  97.92018148992392
# Discrete CMAC:   => g - 27 epoch -  853   => error -  0.020797643776147456  accuracy -  97.92023562238525
# Discrete CMAC:   => g - 27 epoch -  854   => error -  0.02079710559705994  accuracy -  97.920289440294
# Discrete CMAC:   => g - 27 epoch -  855   => error -  0.020796570542948922  accuracy -  97.9203429457051
# Discrete CMAC:   => g - 27 epoch -  856   => error -  0.020796038593413835  accuracy -  97.92039614065861
# Discrete CMAC:   => g - 27 epoch -  857   => error -  0.02079550972820199  accuracy -  97.9204490271798
# Discrete CMAC:   => g - 27 epoch -  858   => error -  0.02079498392720669  accuracy -  97.92050160727933
# Discrete CMAC:   => g - 27 epoch -  859   => error -  0.020794461170466905  accuracy -  97.92055388295331
# Discrete CMAC:   => g - 27 epoch -  860   => error -  0.020793941438165486  accuracy -  97.92060585618346
# Discrete CMAC:   => g - 27 epoch -  861   => error -  0.020793424710628505  accuracy -  97.92065752893716
# Discrete CMAC:   => g - 27 epoch -  862   => error -  0.020792910968323808  accuracy -  97.92070890316762
# Discrete CMAC:   => g - 27 epoch -  863   => error -  0.020792400191860128  accuracy -  97.92075998081398
# Discrete CMAC:   => g - 27 epoch -  864   => error -  0.020791892361985753  accuracy -  97.92081076380143
# Discrete CMAC:   => g - 27 epoch -  865   => error -  0.02079138745958775  accuracy -  97.92086125404123
# Discrete CMAC:   => g - 27 epoch -  866   => error -  0.020790885465690634  accuracy -  97.92091145343093
# Discrete CMAC:   => g - 27 epoch -  867   => error -  0.02079038636145536  accuracy -  97.92096136385446
# Discrete CMAC:   => g - 27 epoch -  868   => error -  0.020789890128178223  accuracy -  97.92101098718217
# Discrete CMAC:   => g - 27 epoch -  869   => error -  0.020789396747289968  accuracy -  97.921060325271
# Discrete CMAC:   => g - 27 epoch -  870   => error -  0.02078890620035445  accuracy -  97.92110937996455
# Discrete CMAC:   => g - 27 epoch -  871   => error -  0.02078841846906787  accuracy -  97.92115815309322
# Discrete CMAC:   => g - 27 epoch -  872   => error -  0.020787933535257652  accuracy -  97.92120664647423
# Discrete CMAC:   => g - 27 epoch -  873   => error -  0.02078745138088145  accuracy -  97.92125486191185
# Discrete CMAC:   => g - 27 epoch -  874   => error -  0.020786971988025926  accuracy -  97.92130280119741
# Discrete CMAC:   => g - 27 epoch -  875   => error -  0.020786495338906086  accuracy -  97.92135046610939
# Discrete CMAC:   => g - 27 epoch -  876   => error -  0.020786021415864053  accuracy -  97.9213978584136
# Discrete CMAC:   => g - 27 epoch -  877   => error -  0.020785550201368186  accuracy -  97.92144497986318
# Discrete CMAC:   => g - 27 epoch -  878   => error -  0.020785081678011963  accuracy -  97.9214918321988
# Discrete CMAC:   => g - 27 epoch -  879   => error -  0.020784615828513098  accuracy -  97.9215384171487
# Discrete CMAC:   => g - 27 epoch -  880   => error -  0.02078415263571265  accuracy -  97.92158473642874
# Discrete CMAC:   => g - 27 epoch -  881   => error -  0.020783692082574023  accuracy -  97.9216307917426
# Discrete CMAC:   => g - 27 epoch -  882   => error -  0.020783234152181973  accuracy -  97.9216765847818
# Discrete CMAC:   => g - 27 epoch -  883   => error -  0.0207827788277416  accuracy -  97.92172211722584
# Discrete CMAC:   => g - 27 epoch -  884   => error -  0.020782326092577463  accuracy -  97.92176739074225
# Discrete CMAC:   => g - 27 epoch -  885   => error -  0.02078187593013303  accuracy -  97.9218124069867
# Discrete CMAC:   => g - 27 epoch -  886   => error -  0.020781428323968898  accuracy -  97.92185716760311
# Discrete CMAC:   => g - 27 epoch -  887   => error -  0.020780983257762897  accuracy -  97.9219016742237
# Discrete CMAC:   => g - 27 epoch -  888   => error -  0.02078054071530855  accuracy -  97.92194592846914
# Discrete CMAC:   => g - 27 epoch -  889   => error -  0.020780100680514058  accuracy -  97.92198993194859
# Discrete CMAC:   => g - 27 epoch -  890   => error -  0.020779663137402093  accuracy -  97.9220336862598
# Discrete CMAC:   => g - 27 epoch -  891   => error -  0.020779228070108346  accuracy -  97.92207719298916
# Discrete CMAC:   => g - 27 epoch -  892   => error -  0.02077879546288064  accuracy -  97.92212045371194
# Discrete CMAC:   => g - 27 epoch -  893   => error -  0.020778365300078483  accuracy -  97.92216346999216
# Discrete CMAC:   => g - 27 epoch -  894   => error -  0.020777937566171856  accuracy -  97.92220624338282
# Discrete CMAC:   => g - 27 epoch -  895   => error -  0.020777512245740537  accuracy -  97.92224877542594
# Discrete CMAC:   => g - 27 epoch -  896   => error -  0.020777089323473108  accuracy -  97.9222910676527
# Discrete CMAC:   => g - 27 epoch -  897   => error -  0.020776668784166286  accuracy -  97.92233312158338
# Discrete CMAC:   => g - 27 epoch -  898   => error -  0.020776250612723923  accuracy -  97.92237493872761
# Discrete CMAC:   => g - 27 epoch -  899   => error -  0.020775834794156456  accuracy -  97.92241652058435
# Discrete CMAC:   => g - 27 epoch -  900   => error -  0.020775421313579456  accuracy -  97.92245786864206
# Discrete CMAC:   => g - 27 epoch -  901   => error -  0.020775010156213858  accuracy -  97.92249898437862
# Discrete CMAC:   => g - 27 epoch -  902   => error -  0.020774601307384177  accuracy -  97.92253986926158
# Discrete CMAC:   => g - 27 epoch -  903   => error -  0.02077419475251807  accuracy -  97.9225805247482
# Discrete CMAC:   => g - 27 epoch -  904   => error -  0.02077379047714578  accuracy -  97.92262095228543
# Discrete CMAC:   => g - 27 epoch -  905   => error -  0.020773388466899023  accuracy -  97.9226611533101
# Discrete CMAC:   => g - 27 epoch -  906   => error -  0.02077298870751032  accuracy -  97.92270112924896
# Discrete CMAC:   => g - 27 epoch -  907   => error -  0.02077259118481234  accuracy -  97.92274088151876
# Discrete CMAC:   => g - 27 epoch -  908   => error -  0.020772195884736888  accuracy -  97.9227804115263
# Discrete CMAC:   => g - 27 epoch -  909   => error -  0.020771802793314142  accuracy -  97.92281972066858
# Discrete CMAC:   => g - 27 epoch -  910   => error -  0.02077141189667253  accuracy -  97.92285881033274
# Discrete CMAC:   => g - 27 epoch -  911   => error -  0.020771023181037185  accuracy -  97.92289768189629
# Discrete CMAC:   => g - 27 epoch -  912   => error -  0.020770636632729267  accuracy -  97.92293633672708
# Discrete CMAC:   => g - 27 epoch -  913   => error -  0.020770252238165976  accuracy -  97.92297477618341
# Discrete CMAC:   => g - 27 epoch -  914   => error -  0.02076986998385899  accuracy -  97.9230130016141
# Discrete CMAC:   => g - 27 epoch -  915   => error -  0.020769489856414247  accuracy -  97.92305101435858
# Discrete CMAC:   => g - 27 epoch -  916   => error -  0.02076911184253094  accuracy -  97.92308881574691
# Discrete CMAC:   => g - 27 epoch -  917   => error -  0.02076873592900086  accuracy -  97.92312640709991
# ...
# Discrete CMAC:   => g - 32 epoch -  337   => error -  0.03849951673745444  accuracy -  96.15004832625456
# Discrete CMAC:   => g - 32 epoch -  338   => error -  0.03849828483217321  accuracy -  96.15017151678268
# Discrete CMAC:   => g - 32 epoch -  339   => error -  0.03849707957281534  accuracy -  96.15029204271846
# Discrete CMAC:   => g - 32 epoch -  340   => error -  0.03849590038661166  accuracy -  96.15040996133884
# Discrete CMAC:   => g - 32 epoch -  341   => error -  0.03849474671304054  accuracy -  96.15052532869595
# Discrete CMAC:   => g - 32 epoch -  342   => error -  0.03849361800356843  accuracy -  96.15063819964315
# Discrete CMAC:   => g - 32 epoch -  343   => error -  0.03849251372139495  accuracy -  96.15074862786051
# Discrete CMAC:   => g - 32 epoch -  344   => error -  0.03849143334120342  accuracy -  96.15085666587966
# Discrete CMAC:   => g - 32 epoch -  345   => error -  0.038490376348916944  accuracy -  96.1509623651083
# Discrete CMAC:   => g - 32 epoch -  346   => error -  0.03848934224145928  accuracy -  96.15106577585408
# Discrete CMAC:   => g - 32 epoch -  347   => error -  0.03848833052652145  accuracy -  96.15116694734786
# Discrete CMAC:   => g - 32 epoch -  348   => error -  0.038487340722332064  accuracy -  96.15126592776679
# Discrete CMAC:   => g - 32 epoch -  349   => error -  0.038486372357433574  accuracy -  96.15136276425665
# Discrete CMAC:   => g - 32 epoch -  350   => error -  0.03848542497046237  accuracy -  96.15145750295376
# Discrete CMAC:   => g - 32 epoch -  351   => error -  0.038484498109934706  accuracy -  96.15155018900653
# Discrete CMAC:   => g - 32 epoch -  352   => error -  0.03848359133403556  accuracy -  96.15164086659644
# Discrete CMAC:   => g - 32 epoch -  353   => error -  0.03848270421041322  accuracy -  96.15172957895868
# Discrete CMAC:   => g - 32 epoch -  354   => error -  0.03848183631597768  accuracy -  96.15181636840224
# Discrete CMAC:   => g - 32 epoch -  355   => error -  0.038480987236703124  accuracy -  96.15190127632968
# Discrete CMAC:   => g - 32 epoch -  356   => error -  0.038480156567435087  accuracy -  96.15198434325649
# Discrete CMAC:   => g - 32 epoch -  357   => error -  0.03847934391170149  accuracy -  96.15206560882984
# Discrete CMAC:   => g - 32 epoch -  358   => error -  0.03847854888152713  accuracy -  96.15214511184729
# Discrete CMAC:   => g - 32 epoch -  359   => error -  0.03847777109725292  accuracy -  96.15222289027471
# Discrete CMAC:   => g - 32 epoch -  360   => error -  0.038477010187358496  accuracy -  96.15229898126415
# Discrete CMAC:   => g - 32 epoch -  361   => error -  0.038476265788288555  accuracy -  96.15237342117115
# Discrete CMAC:   => g - 32 epoch -  362   => error -  0.03847553754428301  accuracy -  96.1524462455717
# Discrete CMAC:   => g - 32 epoch -  363   => error -  0.0384748251072109  accuracy -  96.1525174892789
# Discrete CMAC:   => g - 32 epoch -  364   => error -  0.03847412813640727  accuracy -  96.15258718635927
# Discrete CMAC:   => g - 32 epoch -  365   => error -  0.038473446298514014  accuracy -  96.1526553701486
# Discrete CMAC:   => g - 32 epoch -  366   => error -  0.03847277926732384  accuracy -  96.15272207326761
# Discrete CMAC:   => g - 32 epoch -  367   => error -  0.038472126723627875  accuracy -  96.15278732763721
# Discrete CMAC:   => g - 32 epoch -  368   => error -  0.03847148835506575  accuracy -  96.15285116449343
# Discrete CMAC:   => g - 32 epoch -  369   => error -  0.038470863855979975  accuracy -  96.152913614402
# Discrete CMAC:   => g - 32 epoch -  370   => error -  0.03847025292727213  accuracy -  96.15297470727279
# Discrete CMAC:   => g - 32 epoch -  371   => error -  0.038469655276263226  accuracy -  96.15303447237368
# Discrete CMAC:   => g - 32 epoch -  372   => error -  0.03846907061655658  accuracy -  96.15309293834434
# Discrete CMAC:   => g - 32 epoch -  373   => error -  0.03846849866790325  accuracy -  96.15315013320968
# Discrete CMAC:   => g - 32 epoch -  374   => error -  0.03846793915607072  accuracy -  96.15320608439293
# Discrete CMAC:   => g - 32 epoch -  375   => error -  0.038467391812714635  accuracy -  96.15326081872854
# Discrete CMAC:   => g - 32 epoch -  376   => error -  0.03846685637525249  accuracy -  96.15331436247475
# Discrete CMAC:   => g - 32 epoch -  377   => error -  0.038466332586740926  accuracy -  96.15336674132591
# Discrete CMAC:   => g - 32 epoch -  378   => error -  0.03846582019575484  accuracy -  96.15341798042452
# Discrete CMAC:   => g - 32 epoch -  379   => error -  0.038465318956269146  accuracy -  96.15346810437309
# Discrete CMAC:   => g - 32 epoch -  380   => error -  0.03846482862754397  accuracy -  96.1535171372456
# Discrete CMAC:   => g - 32 epoch -  381   => error -  0.038464348974011076  accuracy -  96.15356510259889
# Discrete CMAC:   => g - 32 epoch -  382   => error -  0.03846387976516319  accuracy -  96.15361202348367
# Discrete CMAC:   => g - 32 epoch -  383   => error -  0.03846342077544607  accuracy -  96.1536579224554
# Discrete CMAC:   => g - 32 epoch -  384   => error -  0.03846297178415248  accuracy -  96.15370282158476
# Discrete CMAC:   => g - 32 epoch -  385   => error -  0.03846253257531784  accuracy -  96.15374674246821
# Discrete CMAC:   => g - 32 epoch -  386   => error -  0.03846210293761976  accuracy -  96.15378970623803
# Discrete CMAC:   => g - 32 epoch -  387   => error -  0.03846168266427774  accuracy -  96.15383173357223
# Discrete CMAC:   => g - 32 epoch -  388   => error -  0.03846127155295653  accuracy -  96.15387284470435
# Discrete CMAC:   => g - 32 epoch -  389   => error -  0.038460869405670506  accuracy -  96.15391305943295
# Discrete CMAC:   => g - 32 epoch -  390   => error -  0.03846047602869096  accuracy -  96.15395239713091
# Discrete CMAC:   => g - 32 epoch -  391   => error -  0.03846009123245475  accuracy -  96.15399087675452
# Discrete CMAC:   => g - 32 epoch -  392   => error -  0.03845971483147492  accuracy -  96.1540285168525
# Discrete CMAC:   => g - 32 epoch -  393   => error -  0.038459346644253656  accuracy -  96.15406533557463
# Discrete CMAC:   => g - 32 epoch -  394   => error -  0.03845898649319679  accuracy -  96.15410135068032
# Discrete CMAC:   => g - 32 epoch -  395   => error -  0.038458634204529885  accuracy -  96.15413657954701
# Discrete CMAC:   => g - 32 epoch -  396   => error -  0.038458289608216956  accuracy -  96.15417103917831
# Discrete CMAC:   => g - 32 epoch -  397   => error -  0.038457952537879536  accuracy -  96.15420474621205
# Discrete CMAC:   => g - 32 epoch -  398   => error -  0.038457622830719296  accuracy -  96.15423771692807
# Discrete CMAC:   => g - 32 epoch -  399   => error -  0.038457300327440436  accuracy -  96.15426996725596
# Discrete CMAC:   => g - 32 epoch -  400   => error -  0.03845698487217519  accuracy -  96.15430151278248
# Discrete CMAC:   => g - 32 epoch -  401   => error -  0.0384566763124099  accuracy -  96.15433236875901
# Discrete CMAC:   => g - 32 epoch -  402   => error -  0.03845637449891348  accuracy -  96.15436255010866
# Discrete CMAC:   => g - 32 epoch -  403   => error -  0.038456079285666855  accuracy -  96.15439207143332
# Discrete CMAC:   => g - 32 epoch -  404   => error -  0.0384557905297942  accuracy -  96.15442094702058
# Discrete CMAC:   => g - 32 epoch -  405   => error -  0.03845550809149523  accuracy -  96.15444919085047
# Discrete CMAC:   => g - 32 epoch -  406   => error -  0.03845523183397981  accuracy -  96.15447681660201
# Discrete CMAC:   => g - 32 epoch -  407   => error -  0.038454961623402784  accuracy -  96.15450383765972
# Discrete CMAC:   => g - 32 epoch -  408   => error -  0.038454697328801135  accuracy -  96.15453026711988
# Discrete CMAC:   => g - 32 epoch -  409   => error -  0.038454438822032144  accuracy -  96.15455611779679
# Discrete CMAC:   => g - 32 epoch -  410   => error -  0.038454185977712774  accuracy -  96.15458140222873
# Discrete CMAC:   => g - 32 epoch -  411   => error -  0.038453938673160715  accuracy -  96.15460613268392
# Discrete CMAC:   => g - 32 epoch -  412   => error -  0.03845369678833588  accuracy -  96.15463032116641
# Discrete CMAC:   => g - 32 epoch -  413   => error -  0.03845346020578455  accuracy -  96.15465397942154
# Discrete CMAC:   => g - 32 epoch -  414   => error -  0.038453228810582885  accuracy -  96.1546771189417
# Discrete CMAC:   => g - 32 epoch -  415   => error -  0.038453002490283605  accuracy -  96.15469975097164
# Discrete CMAC:   => g - 32 epoch -  416   => error -  0.038452781134861946  accuracy -  96.15472188651381
# Discrete CMAC:   => g - 32 epoch -  417   => error -  0.038452564636664466  accuracy -  96.15474353633356
# Discrete CMAC:   => g - 32 epoch -  418   => error -  0.03845235289035742  accuracy -  96.15476471096426
# Discrete CMAC:   => g - 32 epoch -  419   => error -  0.03845214579287748  accuracy -  96.15478542071226
# Discrete CMAC:   => g - 32 epoch -  420   => error -  0.03845194324338275  accuracy -  96.15480567566172
# Discrete CMAC:   => g - 32 epoch -  421   => error -  0.03845174514320526  accuracy -  96.15482548567947
# Discrete CMAC:   => g - 32 epoch -  422   => error -  0.03845155139580381  accuracy -  96.15484486041962
# Discrete CMAC:   => g - 32 epoch -  423   => error -  0.03845136190671894  accuracy -  96.1548638093281
# Discrete CMAC:   => g - 32 epoch -  424   => error -  0.0384511765835277  accuracy -  96.15488234164722
# Discrete CMAC:   => g - 32 epoch -  425   => error -  0.03845099533580021  accuracy -  96.15490046641997
# Discrete CMAC:   => g - 32 epoch -  426   => error -  0.0384508180750569  accuracy -  96.1549181924943
# Discrete CMAC:   => g - 32 epoch -  427   => error -  0.038450644714726145  accuracy -  96.15493552852739
# Discrete CMAC:   => g - 32 epoch -  428   => error -  0.038450475170103804  accuracy -  96.15495248298961
# Discrete CMAC:   => g - 32 epoch -  429   => error -  0.03845030935831306  accuracy -  96.1549690641687
# Discrete CMAC:   => g - 32 epoch -  430   => error -  0.03845014719826456  accuracy -  96.15498528017355
# Discrete CMAC:   => g - 32 epoch -  431   => error -  0.03844998861061877  accuracy -  96.15500113893812
# Discrete CMAC:   => g - 32 epoch -  432   => error -  0.03844983351774811  accuracy -  96.15501664822519
# Discrete CMAC:   => g - 32 epoch -  433   => error -  0.03844968184369979  accuracy -  96.15503181563002
# Discrete CMAC:   => g - 32 epoch -  434   => error -  0.03844953351416036  accuracy -  96.15504664858396
# Discrete CMAC:   => g - 32 epoch -  435   => error -  0.0384493884564201  accuracy -  96.155061154358
# Discrete CMAC:   => g - 32 epoch -  436   => error -  0.03844924659933879  accuracy -  96.15507534006612
# Discrete CMAC:   => g - 32 epoch -  437   => error -  0.038449107873312016  accuracy -  96.1550892126688
# Discrete CMAC:   => g - 32 epoch -  438   => error -  0.038448972210237464  accuracy -  96.15510277897626
# Discrete CMAC:   => g - 32 epoch -  439   => error -  0.03844883954348388  accuracy -  96.15511604565161
# Discrete CMAC:   => g - 32 epoch -  440   => error -  0.038448709807858084  accuracy -  96.15512901921419
# Discrete CMAC:   => g - 32 epoch -  441   => error -  0.038448582939575204  accuracy -  96.15514170604249
# Discrete CMAC:   => g - 32 epoch -  442   => error -  0.0384484588762275  accuracy -  96.15515411237725
# Discrete CMAC:   => g - 32 epoch -  443   => error -  0.03844833755675536  accuracy -  96.15516624432446
# Discrete CMAC:   => g - 32 epoch -  444   => error -  0.03844821892141803  accuracy -  96.15517810785819
# Discrete CMAC:   => g - 32 epoch -  445   => error -  0.03844810291176526  accuracy -  96.15518970882347
# Discrete CMAC:   => g - 32 epoch -  446   => error -  0.03844798947060957  accuracy -  96.15520105293905
# Discrete CMAC:   => g - 32 epoch -  447   => error -  0.03844787854199905  accuracy -  96.15521214580009
# Discrete CMAC:   => g - 32 epoch -  448   => error -  0.038447770071191045  accuracy -  96.1552229928809
# Discrete CMAC:   => g - 32 epoch -  449   => error -  0.038447664004625626  accuracy -  96.15523359953744
# Discrete CMAC:   => g - 32 epoch -  450   => error -  0.038447560289900706  accuracy -  96.15524397100992
# Discrete CMAC:   => g - 32 epoch -  451   => error -  0.03844745887574674  accuracy -  96.15525411242533
# Discrete CMAC:   => g - 32 epoch -  452   => error -  0.038447359712002305  accuracy -  96.15526402879976
# Discrete CMAC:   => g - 33 epoch -  1   => error -  1.9484369392152547  accuracy -  -94.84369392152547
# Discrete CMAC:   => g - 33 epoch -  2   => error -  0.9671361269589073  accuracy -  3.286387304109273
# Discrete CMAC:   => g - 33 epoch -  3   => error -  0.4842902457062216  accuracy -  51.57097542937784
# Discrete CMAC:   => g - 33 epoch -  4   => error -  0.2506227912476535  accuracy -  74.93772087523465
# Discrete CMAC:   => g - 33 epoch -  5   => error -  0.14388496708928133  accuracy -  85.61150329107187
# Discrete CMAC:   => g - 33 epoch -  6   => error -  0.10179641568509445  accuracy -  89.82035843149056
# Discrete CMAC:   => g - 33 epoch -  7   => error -  0.08840803452257429  accuracy -  91.15919654774257
# Discrete CMAC:   => g - 33 epoch -  8   => error -  0.08476575548566467  accuracy -  91.52342445143353
# Discrete CMAC:   => g - 33 epoch -  9   => error -  0.08382855743178952  accuracy -  91.61714425682105
# Discrete CMAC:   => g - 33 epoch -  10   => error -  0.08358693727589672  accuracy -  91.64130627241033
# Discrete CMAC:   => g - 33 epoch -  11   => error -  0.08352245076140885  accuracy -  91.64775492385911
# Discrete CMAC:   => g - 33 epoch -  12   => error -  0.08350407117414216  accuracy -  91.64959288258578
# Discrete CMAC:   => g - 33 epoch -  13   => error -  0.08349829251610774  accuracy -  91.65017074838923
# Discrete CMAC:   => g - 33 epoch -  14   => error -  0.08349624527894117  accuracy -  91.65037547210588
# Discrete CMAC:   => g - 33 epoch -  15   => error -  0.08349543114152236  accuracy -  91.65045688584776
# Discrete CMAC:   => g - 33 epoch -  16   => error -  0.08349507698392777  accuracy -  91.65049230160722
# Discrete CMAC:   => g - 33 epoch -  17   => error -  0.08349491366040462  accuracy -  91.65050863395953
# Discrete CMAC:   => g - 33 epoch -  18   => error -  0.08349483576222494  accuracy -  91.6505164237775
# Discrete CMAC:   => g - 34 epoch -  1   => error -  2.007528744446974  accuracy -  -100.7528744446974
# Discrete CMAC:   => g - 34 epoch -  2   => error -  0.9962970651598303  accuracy -  0.37029348401697026
# Discrete CMAC:   => g - 34 epoch -  3   => error -  0.4985620874471164  accuracy -  50.14379125528836
# Discrete CMAC:   => g - 34 epoch -  4   => error -  0.2573909609278844  accuracy -  74.26090390721156
# Discrete CMAC:   => g - 34 epoch -  5   => error -  0.1467875213296731  accuracy -  85.3212478670327
# Discrete CMAC:   => g - 34 epoch -  6   => error -  0.1028103860910845  accuracy -  89.71896139089155
# Discrete CMAC:   => g - 34 epoch -  7   => error -  0.08869731781393841  accuracy -  91.13026821860616
# Discrete CMAC:   => g - 34 epoch -  8   => error -  0.08484098476698643  accuracy -  91.51590152330135
# Discrete CMAC:   => g - 34 epoch -  9   => error -  0.08384782225994925  accuracy -  91.61521777400507
# Discrete CMAC:   => g - 34 epoch -  10   => error -  0.08359198212879615  accuracy -  91.64080178712038
# Discrete CMAC:   => g - 34 epoch -  11   => error -  0.08352384232062504  accuracy -  91.6476157679375
# Discrete CMAC:   => g - 34 epoch -  12   => error -  0.08350448884616934  accuracy -  91.64955111538306
# Discrete CMAC:   => g - 34 epoch -  13   => error -  0.08349843282802372  accuracy -  91.65015671719763
# Discrete CMAC:   => g - 34 epoch -  14   => error -  0.0834962984571408  accuracy -  91.65037015428592
# Discrete CMAC:   => g - 34 epoch -  15   => error -  0.0834954534760145  accuracy -  91.65045465239855
# Discrete CMAC:   => g - 34 epoch -  16   => error -  0.08349508706128006  accuracy -  91.650491293872
# Discrete CMAC:   => g - 34 epoch -  17   => error -  0.08349491840841572  accuracy -  91.65050815915843
# Discrete CMAC:   => g - 34 epoch -  18   => error -  0.08349483805328639  accuracy -  91.65051619467135

# %% [markdown]
# 2. Program a Continuous CMAC by allowing partial cell overlap, and modifying
# the weight update rule accordingly. Use only 35 weights weights for your CMAC,
# and sample your function at 100 evenly spaced points. Use 70 for training and 30
# for testing. Report the accuracy of your CMAC network using only the 30 test
# points. Compare the output of the Discrete CMAC with that of the Continuous CMAC.

# %%
# Child class of CMAC for continuous case
class ContinuousCMAC(CMAC):

    def __init__(self, gen_factor, num_weights):
        CMAC.__init__(self, gen_factor, num_weights)

    def get_assoc_vec_ind(self, input_val, num_of_assoc_vec, input_min, input_max):
        if input_val < input_min:
            return 1
        elif input_val > input_max:
            return num_of_assoc_vec-1
        else:
            proportion_ind = (num_of_assoc_vec-2) * ((input_val - input_min)/(input_max - input_min)) + 1
            return proportion_ind

    '''  For continuous CMAC we need to consider some portion of adjacent
              windows too for consecutive input values.
        To consider the window of adjacent weights, this function return a set of two indices
            where the sample input value lies
            e.g. if the value = 2.5564 and it lies between the samples 2.4 (at ind=3) 
                and 2.9(at ind=4) (values in the assoc_input_vector), 
                then this function will return 2.5566 -> (3,4)  
    '''
    def process_association_map(self, data, input_min, input_max):
        num_of_assoc_vec = self.num_weights + 1 - self.gen_factor
        for ind, data_val in enumerate(data):
            assoc_vec_ind = self.get_assoc_vec_ind(data_val[0], num_of_assoc_vec, input_min, input_max)
            assoc_vec_ind_flr = int(math.floor(assoc_vec_ind))
            assoc_vec_ind_ceil = int(math.ceil(assoc_vec_ind))
            
            if (assoc_vec_ind_flr != assoc_vec_ind_ceil):
                self.association_map[data_val[0]] = (assoc_vec_ind_flr, assoc_vec_ind_ceil)
            else:
                self.association_map[data_val[0]] = (assoc_vec_ind_flr, 0)
    
    
    def train(self, train_data, input_min, input_max, total_epoch = 5000, learning_rate = 0.01):
        self.weight_vec = np.ones(self.num_weights) 
        input_X_vec = np.linspace(input_min, input_max, self.num_weights + 1 - self.gen_factor)
        alpha = learning_rate
        epoch = 0

        self.association_map = {}
        self.process_association_map(train_data, input_min, input_max)

        is_converged = False
        prev_error = 0
        new_error = 0
        start_time = time.time()

        while epoch <= total_epoch and not is_converged:
            prev_error = new_error
            for ind, train_val in enumerate(train_data):
                asc_wt_ind_flr = self.association_map[train_val[0]][0]
                asc_wt_ind_ceil = self.association_map[train_val[0]][1]
                
                left_common = np.abs(input_X_vec[asc_wt_ind_flr] - train_val[0])
                right_common = np.abs(input_X_vec[asc_wt_ind_ceil] - train_val[0])
                
                left_contri_ratio = right_common/(left_common + right_common)
                right_contri_ratio = left_common/(left_common + right_common)
                
                y_output = (left_contri_ratio * np.sum(self.weight_vec[asc_wt_ind_flr: asc_wt_ind_flr + self.gen_factor])) + (right_contri_ratio * np.sum(self.weight_vec[asc_wt_ind_ceil: asc_wt_ind_ceil + self.gen_factor]))
                
                error = train_val[1] - y_output
                correction = alpha*error/self.gen_factor
                
                self.weight_vec[asc_wt_ind_flr: (asc_wt_ind_flr + self.gen_factor)] = \
                                            [(self.weight_vec[ind] + correction) for ind in range(asc_wt_ind_flr, (asc_wt_ind_flr + self.gen_factor))]
                
                self.weight_vec[asc_wt_ind_ceil: (asc_wt_ind_ceil + self.gen_factor)] = \
                                            [(self.weight_vec[ind] + correction) for ind in range(asc_wt_ind_ceil, (asc_wt_ind_ceil + self.gen_factor))]
                
            
            intermediate_output, accuracy = self.predict(train_data, input_min, input_max, False)
            new_error = 1 - accuracy
            if np.abs(prev_error - new_error) < 0.0000001:
                is_converged = True
                
                
            epoch = epoch + 1
            print("Continuous CMAC: ", " => g -", self.gen_factor, "epoch - ", epoch, "  => error - ", new_error, " accuracy - ", accuracy*100)
        
        end_time = time.time()
        process_time = end_time - start_time
        return process_time, np.copy(self.weight_vec)

    def calculate_error(self, y_predict, y_expected):
        error = np.subtract(y_expected, y_predict)
        error_sq = np.power(error, 2)
        sum_error_sq = np.sum(error_sq)
        total_error = np.sqrt(sum_error_sq)/len(y_expected)
        return total_error
    
    
    def predict(self, test_data, input_min, input_max, re_process_asso_map = True):
        output = []

        input_X_vec = np.linspace(input_min, input_max, self.num_weights + 1 - self.gen_factor)

        if re_process_asso_map:
            self.process_association_map(test_data, input_min, input_max)
        
        for ind, test_val in enumerate(test_data):
            asc_wt_ind_flr = self.association_map[test_val[0]][0]
            asc_wt_ind_ceil = self.association_map[test_val[0]][1]

            left_common = np.abs(input_X_vec[asc_wt_ind_flr] - test_val[0])
            right_common = np.abs(input_X_vec[asc_wt_ind_ceil] - test_val[0])

            left_contri_ratio = right_common/(left_common + right_common)
            right_contri_ratio = left_common/(left_common + right_common)

            y_output = (left_contri_ratio * np.sum(self.weight_vec[asc_wt_ind_flr: asc_wt_ind_flr + self.gen_factor])) + (right_contri_ratio * np.sum(self.weight_vec[asc_wt_ind_ceil: asc_wt_ind_ceil + self.gen_factor]))

            output.append(y_output)
        
        error = self.calculate_error(output, test_data[:, 1])
        accuracy = 1 - error
        return output, accuracy

# %%
# The process to the train the continuous CMAC was similar 
#     to that of the discrete CMAC.
# The only difference here was to consider the proportion of weights 
#     (overlapping window size) to find out which weights are contributing
#     in which proportion.
'''This Code runs discrete and Continuous CMAC models'''

### These lines are repeated from Discrete in case this block run separately###
TWO_PI = 2*np.pi
sample_input = np.linspace(0, TWO_PI, 100)
sample_output = np.sin(sample_input)

total_data = np.column_stack((sample_input, sample_output))
np.random.shuffle(total_data)

train_data = total_data[:70]
test_data = total_data[70:] #30 data points

x_train = train_data[:, 0]
x_test = test_data[:, 0]

y_train = train_data[:, 1]
y_test = test_data[:, 1] 

num_weights = 35

gen_factor_list = range(1, num_weights)

convergence_time_discrete = []
accuracies_discrete = []
#######################

# Continuous variables
convergence_time_continuous = []
accuracies_continuous = []

#continuus class Object
continuous_cmac = ContinuousCMAC(1, num_weights)
discrete_cmac = DiscreteCMAC(1, num_weights)

for gen_factor in gen_factor_list:
      # Discrete CMAC
      discrete_cmac.set_gen_factor(gen_factor)
      process_time_discrete, weight_vec_discrete = discrete_cmac.train(train_data, 0, TWO_PI, 10000)
      y_output_discrete, accuracy_discrete = discrete_cmac.predict(test_data, 0, TWO_PI)

      # Continuous CMAC
      continuous_cmac.set_gen_factor(gen_factor)
      process_time_continuous, weight_vec_continuous = continuous_cmac.train(train_data, 0, TWO_PI, 10000)
      y_output_continuous, accuracy_continuous = continuous_cmac.predict(test_data, 0, TWO_PI)

      #Accuracy and Convergence time
      convergence_time_discrete.append(process_time_discrete)
      accuracies_discrete.append(accuracy_discrete)
      convergence_time_continuous.append(process_time_continuous)
      accuracies_continuous.append(accuracy_continuous)

fig, (ax1, ax2) = plt.subplots(1, 2)
plt.style.use('seaborn-whitegrid')

ax1.set_title('Convergence time v/s Generalization Factor')
ax1.plot(gen_factor_list, convergence_time_discrete, label="Discrete CMAC")
ax1.plot(gen_factor_list, convergence_time_continuous, color = (1,0,0), label="Continuous CMAC") 
ax1.set(xlabel='generalization factor', ylabel='Convergence time')
ax1.legend()
    

ax2.set_title('Accuracy v/s Generalization Factor')
ax2.plot(gen_factor_list, accuracies_discrete, label="Discrete CMAC")
ax2.plot(gen_factor_list, accuracies_continuous, color = (1,0,0), label="Continuous CMAC")
ax2.set(xlabel='generalization factor', ylabel='Accuracy')
ax2.legend()

plt.show()
# Out:
# Streaming output truncated to the last 5000 lines.
# Discrete CMAC:   => g - 7 epoch -  475   => error -  0.009464605277584082  accuracy -  99.0535394722416
# Discrete CMAC:   => g - 7 epoch -  476   => error -  0.009455236270323297  accuracy -  99.05447637296767
# Discrete CMAC:   => g - 7 epoch -  477   => error -  0.00944589496472148  accuracy -  99.05541050352785
# Discrete CMAC:   => g - 7 epoch -  478   => error -  0.00943658125295288  accuracy -  99.05634187470471
# Discrete CMAC:   => g - 7 epoch -  479   => error -  0.009427295027814586  accuracy -  99.05727049721854
# Discrete CMAC:   => g - 7 epoch -  480   => error -  0.009418036182719969  accuracy -  99.05819638172801
# Discrete CMAC:   => g - 7 epoch -  481   => error -  0.009408804611693022  accuracy -  99.0591195388307
# Discrete CMAC:   => g - 7 epoch -  482   => error -  0.009399600209362036  accuracy -  99.0600399790638
# Discrete CMAC:   => g - 7 epoch -  483   => error -  0.00939042287095393  accuracy -  99.06095771290461
# Discrete CMAC:   => g - 7 epoch -  484   => error -  0.009381272492288595  accuracy -  99.06187275077114
# Discrete CMAC:   => g - 7 epoch -  485   => error -  0.009372148969772898  accuracy -  99.0627851030227
# Discrete CMAC:   => g - 7 epoch -  486   => error -  0.009363052200395239  accuracy -  99.06369477996047
# Discrete CMAC:   => g - 7 epoch -  487   => error -  0.009353982081720336  accuracy -  99.06460179182797
# Discrete CMAC:   => g - 7 epoch -  488   => error -  0.009344938511883116  accuracy -  99.06550614881169
# Discrete CMAC:   => g - 7 epoch -  489   => error -  0.009335921389584168  accuracy -  99.06640786104158
# Discrete CMAC:   => g - 7 epoch -  490   => error -  0.00932693061408385  accuracy -  99.06730693859161
# Discrete CMAC:   => g - 7 epoch -  491   => error -  0.009317966085197638  accuracy -  99.06820339148024
# Discrete CMAC:   => g - 7 epoch -  492   => error -  0.00930902770329034  accuracy -  99.06909722967097
# Discrete CMAC:   => g - 7 epoch -  493   => error -  0.009300115369272  accuracy -  99.0699884630728
# Discrete CMAC:   => g - 7 epoch -  494   => error -  0.009291228984591893  accuracy -  99.07087710154082
# Discrete CMAC:   => g - 7 epoch -  495   => error -  0.009282368451234535  accuracy -  99.07176315487655
# Discrete CMAC:   => g - 7 epoch -  496   => error -  0.009273533671714573  accuracy -  99.07264663282854
# Discrete CMAC:   => g - 7 epoch -  497   => error -  0.009264724549071679  accuracy -  99.07352754509283
# Discrete CMAC:   => g - 7 epoch -  498   => error -  0.009255940986866551  accuracy -  99.07440590131334
# Discrete CMAC:   => g - 7 epoch -  499   => error -  0.009247182889175809  accuracy -  99.07528171108243
# Discrete CMAC:   => g - 7 epoch -  500   => error -  0.009238450160587552  accuracy -  99.07615498394125
# Discrete CMAC:   => g - 7 epoch -  501   => error -  0.009229742706197253  accuracy -  99.07702572938028
# Discrete CMAC:   => g - 7 epoch -  502   => error -  0.009221060431602757  accuracy -  99.07789395683973
# Discrete CMAC:   => g - 7 epoch -  503   => error -  0.009212403242900402  accuracy -  99.07875967570996
# Discrete CMAC:   => g - 7 epoch -  504   => error -  0.009203771046680576  accuracy -  99.07962289533194
# Discrete CMAC:   => g - 7 epoch -  505   => error -  0.009195163750023494  accuracy -  99.08048362499765
# Discrete CMAC:   => g - 7 epoch -  506   => error -  0.009186581260495097  accuracy -  99.08134187395049
# Discrete CMAC:   => g - 7 epoch -  507   => error -  0.009178023486142828  accuracy -  99.08219765138571
# Discrete CMAC:   => g - 7 epoch -  508   => error -  0.009169490335491637  accuracy -  99.08305096645084
# Discrete CMAC:   => g - 7 epoch -  509   => error -  0.009160981717540095  accuracy -  99.08390182824598
# Discrete CMAC:   => g - 7 epoch -  510   => error -  0.0091524975417564  accuracy -  99.08475024582437
# Discrete CMAC:   => g - 7 epoch -  511   => error -  0.009144037718074483  accuracy -  99.08559622819256
# Discrete CMAC:   => g - 7 epoch -  512   => error -  0.0091356021568898  accuracy -  99.08643978431103
# Discrete CMAC:   => g - 7 epoch -  513   => error -  0.009127190769056437  accuracy -  99.08728092309435
# Discrete CMAC:   => g - 7 epoch -  514   => error -  0.009118803465882563  accuracy -  99.08811965341174
# Discrete CMAC:   => g - 7 epoch -  515   => error -  0.009110440159126987  accuracy -  99.0889559840873
# Discrete CMAC:   => g - 7 epoch -  516   => error -  0.009102100760995713  accuracy -  99.08978992390043
# Discrete CMAC:   => g - 7 epoch -  517   => error -  0.00909378518413817  accuracy -  99.09062148158618
# Discrete CMAC:   => g - 7 epoch -  518   => error -  0.009085493341643658  accuracy -  99.09145066583564
# Discrete CMAC:   => g - 7 epoch -  519   => error -  0.009077225147038126  accuracy -  99.0922774852962
# Discrete CMAC:   => g - 7 epoch -  520   => error -  0.009068980514280178  accuracy -  99.09310194857198
# Discrete CMAC:   => g - 7 epoch -  521   => error -  0.009060759357758408  accuracy -  99.09392406422415
# Discrete CMAC:   => g - 7 epoch -  522   => error -  0.00905256159228729  accuracy -  99.09474384077127
# Discrete CMAC:   => g - 7 epoch -  523   => error -  0.009044387133104403  accuracy -  99.09556128668956
# Discrete CMAC:   => g - 7 epoch -  524   => error -  0.009036235895866995  accuracy -  99.0963764104133
# Discrete CMAC:   => g - 7 epoch -  525   => error -  0.009028107796648532  accuracy -  99.09718922033515
# Discrete CMAC:   => g - 7 epoch -  526   => error -  0.00902000275193593  accuracy -  99.09799972480641
# Discrete CMAC:   => g - 7 epoch -  527   => error -  0.009011920678625884  accuracy -  99.09880793213742
# Discrete CMAC:   => g - 7 epoch -  528   => error -  0.009003861494022214  accuracy -  99.09961385059778
# Discrete CMAC:   => g - 7 epoch -  529   => error -  0.008995825115832745  accuracy -  99.10041748841672
# Discrete CMAC:   => g - 7 epoch -  530   => error -  0.008987811462165762  accuracy -  99.10121885378342
# Discrete CMAC:   => g - 7 epoch -  531   => error -  0.008979820451527676  accuracy -  99.10201795484723
# Discrete CMAC:   => g - 7 epoch -  532   => error -  0.008971852002819691  accuracy -  99.10281479971803
# Discrete CMAC:   => g - 7 epoch -  533   => error -  0.008963906035334701  accuracy -  99.10360939646652
# Discrete CMAC:   => g - 7 epoch -  534   => error -  0.008955982468754953  accuracy -  99.1044017531245
# Discrete CMAC:   => g - 7 epoch -  535   => error -  0.00894808122314883  accuracy -  99.10519187768512
# Discrete CMAC:   => g - 7 epoch -  536   => error -  0.008940202218967741  accuracy -  99.10597977810323
# Discrete CMAC:   => g - 7 epoch -  537   => error -  0.008932345377044015  accuracy -  99.1067654622956
# Discrete CMAC:   => g - 7 epoch -  538   => error -  0.008924510618587456  accuracy -  99.10754893814125
# Discrete CMAC:   => g - 7 epoch -  539   => error -  0.008916697865183343  accuracy -  99.10833021348166
# Discrete CMAC:   => g - 7 epoch -  540   => error -  0.00890890703878866  accuracy -  99.10910929612113
# Discrete CMAC:   => g - 7 epoch -  541   => error -  0.008901138061730873  accuracy -  99.10988619382691
# Discrete CMAC:   => g - 7 epoch -  542   => error -  0.00889339085670382  accuracy -  99.11066091432961
# Discrete CMAC:   => g - 7 epoch -  543   => error -  0.008885665346766158  accuracy -  99.11143346532339
# Discrete CMAC:   => g - 7 epoch -  544   => error -  0.008877961455338257  accuracy -  99.11220385446617
# Discrete CMAC:   => g - 7 epoch -  545   => error -  0.008870279106199863  accuracy -  99.11297208938001
# Discrete CMAC:   => g - 7 epoch -  546   => error -  0.008862618223487773  accuracy -  99.11373817765123
# Discrete CMAC:   => g - 7 epoch -  547   => error -  0.008854978731692498  accuracy -  99.11450212683076
# Discrete CMAC:   => g - 7 epoch -  548   => error -  0.008847360555657047  accuracy -  99.11526394443429
# Discrete CMAC:   => g - 7 epoch -  549   => error -  0.008839763620573371  accuracy -  99.11602363794266
# Discrete CMAC:   => g - 7 epoch -  550   => error -  0.0088321878519807  accuracy -  99.11678121480193
# Discrete CMAC:   => g - 7 epoch -  551   => error -  0.008824633175762875  accuracy -  99.11753668242372
# Discrete CMAC:   => g - 7 epoch -  552   => error -  0.008817099518145688  accuracy -  99.11829004818543
# Discrete CMAC:   => g - 7 epoch -  553   => error -  0.008809586805695324  accuracy -  99.11904131943047
# Discrete CMAC:   => g - 7 epoch -  554   => error -  0.008802094965315144  accuracy -  99.11979050346848
# Discrete CMAC:   => g - 7 epoch -  555   => error -  0.00879462392424435  accuracy -  99.12053760757557
# Discrete CMAC:   => g - 7 epoch -  556   => error -  0.008787173610054655  accuracy -  99.12128263899453
# Discrete CMAC:   => g - 7 epoch -  557   => error -  0.008779743950649066  accuracy -  99.12202560493509
# Discrete CMAC:   => g - 7 epoch -  558   => error -  0.008772334874259102  accuracy -  99.12276651257409
# Discrete CMAC:   => g - 7 epoch -  559   => error -  0.00876494630944269  accuracy -  99.12350536905574
# Discrete CMAC:   => g - 7 epoch -  560   => error -  0.008757578185082049  accuracy -  99.1242421814918
# Discrete CMAC:   => g - 7 epoch -  561   => error -  0.00875023043038159  accuracy -  99.12497695696185
# Discrete CMAC:   => g - 7 epoch -  562   => error -  0.008742902974865685  accuracy -  99.12570970251343
# Discrete CMAC:   => g - 7 epoch -  563   => error -  0.00873559574837679  accuracy -  99.12644042516231
# Discrete CMAC:   => g - 7 epoch -  564   => error -  0.008728308681072994  accuracy -  99.1271691318927
# Discrete CMAC:   => g - 7 epoch -  565   => error -  0.008721041703426358  accuracy -  99.12789582965736
# Discrete CMAC:   => g - 7 epoch -  566   => error -  0.008713794746220693  accuracy -  99.12862052537793
# Discrete CMAC:   => g - 7 epoch -  567   => error -  0.008706567740549453  accuracy -  99.12934322594505
# Discrete CMAC:   => g - 7 epoch -  568   => error -  0.008699360617813956  accuracy -  99.1300639382186
# Discrete CMAC:   => g - 7 epoch -  569   => error -  0.008692173309721163  accuracy -  99.13078266902788
# Discrete CMAC:   => g - 7 epoch -  570   => error -  0.008685005748282126  accuracy -  99.13149942517178
# Discrete CMAC:   => g - 7 epoch -  571   => error -  0.008677857865809546  accuracy -  99.13221421341905
# Discrete CMAC:   => g - 7 epoch -  572   => error -  0.008670729594916216  accuracy -  99.13292704050838
# Discrete CMAC:   => g - 7 epoch -  573   => error -  0.008663620868513022  accuracy -  99.1336379131487
# Discrete CMAC:   => g - 7 epoch -  574   => error -  0.00865653161980695  accuracy -  99.13434683801931
# Discrete CMAC:   => g - 7 epoch -  575   => error -  0.008649461782299417  accuracy -  99.13505382177006
# Discrete CMAC:   => g - 7 epoch -  576   => error -  0.008642411289784269  accuracy -  99.13575887102158
# Discrete CMAC:   => g - 7 epoch -  577   => error -  0.008635380076346344  accuracy -  99.13646199236537
# Discrete CMAC:   => g - 7 epoch -  578   => error -  0.008628368076358806  accuracy -  99.13716319236411
# Discrete CMAC:   => g - 7 epoch -  579   => error -  0.008621375224482364  accuracy -  99.13786247755176
# Discrete CMAC:   => g - 7 epoch -  580   => error -  0.008614401455662724  accuracy -  99.13855985443372
# Discrete CMAC:   => g - 7 epoch -  581   => error -  0.008607446705129473  accuracy -  99.13925532948706
# Discrete CMAC:   => g - 7 epoch -  582   => error -  0.008600510908393755  accuracy -  99.13994890916062
# Discrete CMAC:   => g - 7 epoch -  583   => error -  0.008593594001246818  accuracy -  99.14064059987531
# Discrete CMAC:   => g - 7 epoch -  584   => error -  0.008586695919758469  accuracy -  99.14133040802415
# Discrete CMAC:   => g - 7 epoch -  585   => error -  0.008579816600274959  accuracy -  99.14201833997251
# Discrete CMAC:   => g - 7 epoch -  586   => error -  0.008572955979417873  accuracy -  99.14270440205821
# Discrete CMAC:   => g - 7 epoch -  587   => error -  0.008566113994081803  accuracy -  99.14338860059182
# Discrete CMAC:   => g - 7 epoch -  588   => error -  0.008559290581433343  accuracy -  99.14407094185667
# Discrete CMAC:   => g - 7 epoch -  589   => error -  0.008552485678908983  accuracy -  99.1447514321091
# Discrete CMAC:   => g - 7 epoch -  590   => error -  0.008545699224213776  accuracy -  99.14543007757862
# Discrete CMAC:   => g - 7 epoch -  591   => error -  0.008538931155319673  accuracy -  99.14610688446803
# Discrete CMAC:   => g - 7 epoch -  592   => error -  0.008532181410463857  accuracy -  99.14678185895362
# Discrete CMAC:   => g - 7 epoch -  593   => error -  0.008525449928147077  accuracy -  99.14745500718529
# Discrete CMAC:   => g - 7 epoch -  594   => error -  0.008518736647132541  accuracy -  99.14812633528675
# Discrete CMAC:   => g - 7 epoch -  595   => error -  0.008512041506443913  accuracy -  99.14879584935561
# Discrete CMAC:   => g - 7 epoch -  596   => error -  0.008505364445363761  accuracy -  99.14946355546363
# Discrete CMAC:   => g - 7 epoch -  597   => error -  0.00849870540343256  accuracy -  99.15012945965674
# Discrete CMAC:   => g - 7 epoch -  598   => error -  0.008492064320446469  accuracy -  99.15079356795535
# Discrete CMAC:   => g - 7 epoch -  599   => error -  0.008485441136456662  accuracy -  99.15145588635433
# Discrete CMAC:   => g - 7 epoch -  600   => error -  0.008478835791767003  accuracy -  99.1521164208233
# Discrete CMAC:   => g - 7 epoch -  601   => error -  0.008472248226933154  accuracy -  99.15277517730668
# Discrete CMAC:   => g - 7 epoch -  602   => error -  0.00846567838276091  accuracy -  99.15343216172391
# Discrete CMAC:   => g - 7 epoch -  603   => error -  0.008459126200304867  accuracy -  99.15408737996951
# Discrete CMAC:   => g - 7 epoch -  604   => error -  0.008452591620866867  accuracy -  99.15474083791331
# Discrete CMAC:   => g - 7 epoch -  605   => error -  0.008446074585994667  accuracy -  99.15539254140053
# Discrete CMAC:   => g - 7 epoch -  606   => error -  0.008439575037480496  accuracy -  99.15604249625196
# Discrete CMAC:   => g - 7 epoch -  607   => error -  0.00843309291735983  accuracy -  99.15669070826402
# Discrete CMAC:   => g - 7 epoch -  608   => error -  0.008426628167909511  accuracy -  99.15733718320905
# Discrete CMAC:   => g - 7 epoch -  609   => error -  0.008420180731647076  accuracy -  99.15798192683529
# Discrete CMAC:   => g - 7 epoch -  610   => error -  0.00841375055132898  accuracy -  99.1586249448671
# Discrete CMAC:   => g - 7 epoch -  611   => error -  0.00840733756994927  accuracy -  99.15926624300508
# Discrete CMAC:   => g - 7 epoch -  612   => error -  0.008400941730738243  accuracy -  99.15990582692618
# Discrete CMAC:   => g - 7 epoch -  613   => error -  0.008394562977161457  accuracy -  99.16054370228386
# Discrete CMAC:   => g - 7 epoch -  614   => error -  0.008388201252917837  accuracy -  99.16117987470821
# Discrete CMAC:   => g - 7 epoch -  615   => error -  0.0083818565019389  accuracy -  99.16181434980611
# Discrete CMAC:   => g - 7 epoch -  616   => error -  0.0083755286683872  accuracy -  99.16244713316128
# Discrete CMAC:   => g - 7 epoch -  617   => error -  0.008369217696655107  accuracy -  99.16307823033449
# Discrete CMAC:   => g - 7 epoch -  618   => error -  0.008362923531363364  accuracy -  99.16370764686366
# Discrete CMAC:   => g - 7 epoch -  619   => error -  0.008356646117360422  accuracy -  99.16433538826396
# Discrete CMAC:   => g - 7 epoch -  620   => error -  0.008350385399720328  accuracy -  99.16496146002797
# Discrete CMAC:   => g - 7 epoch -  621   => error -  0.008344141323742171  accuracy -  99.16558586762578
# Discrete CMAC:   => g - 7 epoch -  622   => error -  0.00833791383494853  accuracy -  99.16620861650514
# Discrete CMAC:   => g - 7 epoch -  623   => error -  0.008331702879084357  accuracy -  99.16682971209157
# Discrete CMAC:   => g - 7 epoch -  624   => error -  0.008325508402115545  accuracy -  99.16744915978845
# Discrete CMAC:   => g - 7 epoch -  625   => error -  0.00831933035022836  accuracy -  99.16806696497716
# Discrete CMAC:   => g - 7 epoch -  626   => error -  0.008313168669827453  accuracy -  99.16868313301725
# Discrete CMAC:   => g - 7 epoch -  627   => error -  0.008307023307535077  accuracy -  99.16929766924649
# Discrete CMAC:   => g - 7 epoch -  628   => error -  0.00830089421019009  accuracy -  99.16991057898099
# Discrete CMAC:   => g - 7 epoch -  629   => error -  0.0082947813248464  accuracy -  99.17052186751536
# Discrete CMAC:   => g - 7 epoch -  630   => error -  0.008288684598771967  accuracy -  99.1711315401228
# Discrete CMAC:   => g - 7 epoch -  631   => error -  0.008282603979447689  accuracy -  99.17173960205523
# Discrete CMAC:   => g - 7 epoch -  632   => error -  0.00827653941456652  accuracy -  99.17234605854335
# Discrete CMAC:   => g - 7 epoch -  633   => error -  0.008270490852031687  accuracy -  99.17295091479683
# Discrete CMAC:   => g - 7 epoch -  634   => error -  0.008264458239956252  accuracy -  99.17355417600437
# Discrete CMAC:   => g - 7 epoch -  635   => error -  0.008258441526661664  accuracy -  99.17415584733384
# Discrete CMAC:   => g - 7 epoch -  636   => error -  0.008252440660676652  accuracy -  99.17475593393233
# Discrete CMAC:   => g - 7 epoch -  637   => error -  0.008246455590736113  accuracy -  99.17535444092638
# Discrete CMAC:   => g - 7 epoch -  638   => error -  0.008240486265780333  accuracy -  99.17595137342197
# Discrete CMAC:   => g - 7 epoch -  639   => error -  0.008234532634953329  accuracy -  99.17654673650466
# Discrete CMAC:   => g - 7 epoch -  640   => error -  0.008228594647602616  accuracy -  99.17714053523974
# Discrete CMAC:   => g - 7 epoch -  641   => error -  0.008222672253277219  accuracy -  99.17773277467228
# Discrete CMAC:   => g - 7 epoch -  642   => error -  0.008216765401727222  accuracy -  99.17832345982728
# Discrete CMAC:   => g - 7 epoch -  643   => error -  0.00821087404290266  accuracy -  99.17891259570973
# Discrete CMAC:   => g - 7 epoch -  644   => error -  0.00820499812695219  accuracy -  99.17950018730478
# Discrete CMAC:   => g - 7 epoch -  645   => error -  0.008199137604222528  accuracy -  99.18008623957775
# Discrete CMAC:   => g - 7 epoch -  646   => error -  0.008193292425256793  accuracy -  99.18067075747432
# Discrete CMAC:   => g - 7 epoch -  647   => error -  0.008187462540794166  accuracy -  99.18125374592059
# Discrete CMAC:   => g - 7 epoch -  648   => error -  0.00818164790176834  accuracy -  99.18183520982316
# Discrete CMAC:   => g - 7 epoch -  649   => error -  0.008175848459306967  accuracy -  99.1824151540693
# Discrete CMAC:   => g - 7 epoch -  650   => error -  0.008170064164730317  accuracy -  99.18299358352697
# Discrete CMAC:   => g - 7 epoch -  651   => error -  0.0081642949695504  accuracy -  99.18357050304496
# Discrete CMAC:   => g - 7 epoch -  652   => error -  0.008158540825470073  accuracy -  99.184145917453
# Discrete CMAC:   => g - 7 epoch -  653   => error -  0.008152801684381927  accuracy -  99.18471983156181
# Discrete CMAC:   => g - 7 epoch -  654   => error -  0.008147077498367516  accuracy -  99.18529225016324
# Discrete CMAC:   => g - 7 epoch -  655   => error -  0.008141368219696243  accuracy -  99.18586317803037
# Discrete CMAC:   => g - 7 epoch -  656   => error -  0.008135673800824472  accuracy -  99.18643261991755
# Discrete CMAC:   => g - 7 epoch -  657   => error -  0.008129994194394419  accuracy -  99.18700058056056
# Discrete CMAC:   => g - 7 epoch -  658   => error -  0.008124329353233484  accuracy -  99.18756706467666
# Discrete CMAC:   => g - 7 epoch -  659   => error -  0.008118679230353143  accuracy -  99.18813207696469
# Discrete CMAC:   => g - 7 epoch -  660   => error -  0.008113043778948281  accuracy -  99.18869562210517
# Discrete CMAC:   => g - 7 epoch -  661   => error -  0.008107422952395638  accuracy -  99.18925770476044
# Discrete CMAC:   => g - 7 epoch -  662   => error -  0.008101816704253806  accuracy -  99.18981832957462
# Discrete CMAC:   => g - 7 epoch -  663   => error -  0.008096224988261458  accuracy -  99.19037750117386
# Discrete CMAC:   => g - 7 epoch -  664   => error -  0.008090647758337122  accuracy -  99.19093522416628
# Discrete CMAC:   => g - 7 epoch -  665   => error -  0.008085084968577738  accuracy -  99.19149150314223
# Discrete CMAC:   => g - 7 epoch -  666   => error -  0.008079536573258439  accuracy -  99.19204634267416
# Discrete CMAC:   => g - 7 epoch -  667   => error -  0.00807400252683066  accuracy -  99.19259974731693
# Discrete CMAC:   => g - 7 epoch -  668   => error -  0.00806848278392247  accuracy -  99.19315172160775
# Discrete CMAC:   => g - 7 epoch -  669   => error -  0.008062977299336804  accuracy -  99.19370227006632
# Discrete CMAC:   => g - 7 epoch -  670   => error -  0.008057486028051009  accuracy -  99.1942513971949
# Discrete CMAC:   => g - 7 epoch -  671   => error -  0.008052008925215737  accuracy -  99.19479910747843
# Discrete CMAC:   => g - 7 epoch -  672   => error -  0.008046545946154393  accuracy -  99.19534540538456
# Discrete CMAC:   => g - 7 epoch -  673   => error -  0.008041097046362022  accuracy -  99.1958902953638
# Discrete CMAC:   => g - 7 epoch -  674   => error -  0.008035662181504644  accuracy -  99.19643378184954
# Discrete CMAC:   => g - 7 epoch -  675   => error -  0.008030241307418473  accuracy -  99.19697586925815
# Discrete CMAC:   => g - 7 epoch -  676   => error -  0.008024834380108703  accuracy -  99.19751656198913
# Discrete CMAC:   => g - 7 epoch -  677   => error -  0.008019441355749168  accuracy -  99.19805586442509
# Discrete CMAC:   => g - 7 epoch -  678   => error -  0.008014062190681348  accuracy -  99.19859378093186
# Discrete CMAC:   => g - 7 epoch -  679   => error -  0.008008696841413365  accuracy -  99.19913031585867
# Discrete CMAC:   => g - 7 epoch -  680   => error -  0.008003345264619433  accuracy -  99.19966547353806
# Discrete CMAC:   => g - 7 epoch -  681   => error -  0.007998007417138964  accuracy -  99.2001992582861
# Discrete CMAC:   => g - 7 epoch -  682   => error -  0.007992683255975686  accuracy -  99.20073167440243
# Discrete CMAC:   => g - 7 epoch -  683   => error -  0.007987372738297083  accuracy -  99.20126272617028
# Discrete CMAC:   => g - 7 epoch -  684   => error -  0.007982075821433399  accuracy -  99.20179241785667
# Discrete CMAC:   => g - 7 epoch -  685   => error -  0.007976792462876858  accuracy -  99.20232075371231
# Discrete CMAC:   => g - 7 epoch -  686   => error -  0.007971522620281002  accuracy -  99.2028477379719
# Discrete CMAC:   => g - 7 epoch -  687   => error -  0.007966266251459797  accuracy -  99.20337337485402
# Discrete CMAC:   => g - 7 epoch -  688   => error -  0.007961023314387194  accuracy -  99.20389766856128
# Discrete CMAC:   => g - 7 epoch -  689   => error -  0.007955793767195907  accuracy -  99.20442062328041
# Discrete CMAC:   => g - 7 epoch -  690   => error -  0.007950577568176853  accuracy -  99.20494224318232
# Discrete CMAC:   => g - 7 epoch -  691   => error -  0.007945374675778494  accuracy -  99.20546253242215
# Discrete CMAC:   => g - 7 epoch -  692   => error -  0.007940185048606052  accuracy -  99.2059814951394
# Discrete CMAC:   => g - 7 epoch -  693   => error -  0.007935008645420627  accuracy -  99.20649913545793
# Discrete CMAC:   => g - 7 epoch -  694   => error -  0.007929845425138748  accuracy -  99.20701545748612
# Discrete CMAC:   => g - 7 epoch -  695   => error -  0.007924695346831157  accuracy -  99.20753046531688
# Discrete CMAC:   => g - 7 epoch -  696   => error -  0.00791955836972269  accuracy -  99.20804416302774
# Discrete CMAC:   => g - 7 epoch -  697   => error -  0.007914434453191177  accuracy -  99.20855655468088
# Discrete CMAC:   => g - 7 epoch -  698   => error -  0.007909323556766767  accuracy -  99.20906764432333
# Discrete CMAC:   => g - 7 epoch -  699   => error -  0.007904225640131046  accuracy -  99.2095774359869
# Discrete CMAC:   => g - 7 epoch -  700   => error -  0.007899140663117032  accuracy -  99.21008593368829
# Discrete CMAC:   => g - 7 epoch -  701   => error -  0.007894068585707403  accuracy -  99.21059314142926
# Discrete CMAC:   => g - 7 epoch -  702   => error -  0.007889009368034716  accuracy -  99.21109906319653
# Discrete CMAC:   => g - 7 epoch -  703   => error -  0.007883962970380298  accuracy -  99.21160370296197
# Discrete CMAC:   => g - 7 epoch -  704   => error -  0.007878929353173691  accuracy -  99.21210706468263
# Discrete CMAC:   => g - 7 epoch -  705   => error -  0.007873908476991542  accuracy -  99.21260915230084
# Discrete CMAC:   => g - 7 epoch -  706   => error -  0.007868900302557824  accuracy -  99.21310996974422
# Discrete CMAC:   => g - 7 epoch -  707   => error -  0.00786390479074206  accuracy -  99.2136095209258
# Discrete CMAC:   => g - 7 epoch -  708   => error -  0.007858921902559546  accuracy -  99.21410780974405
# Discrete CMAC:   => g - 7 epoch -  709   => error -  0.007853951599170239  accuracy -  99.21460484008297
# Discrete CMAC:   => g - 7 epoch -  710   => error -  0.007848993841878094  accuracy -  99.21510061581219
# Discrete CMAC:   => g - 7 epoch -  711   => error -  0.007844048592130726  accuracy -  99.21559514078693
# Discrete CMAC:   => g - 7 epoch -  712   => error -  0.007839115811518083  accuracy -  99.21608841884819
# Discrete CMAC:   => g - 7 epoch -  713   => error -  0.007834195461772775  accuracy -  99.21658045382273
# Discrete CMAC:   => g - 7 epoch -  714   => error -  0.007829287504768523  accuracy -  99.21707124952314
# Discrete CMAC:   => g - 7 epoch -  715   => error -  0.007824391902519823  accuracy -  99.21756080974802
# Discrete CMAC:   => g - 7 epoch -  716   => error -  0.007819508617181503  accuracy -  99.21804913828186
# Discrete CMAC:   => g - 7 epoch -  717   => error -  0.007814637611048059  accuracy -  99.2185362388952
# Discrete CMAC:   => g - 7 epoch -  718   => error -  0.00780977884655254  accuracy -  99.21902211534474
# Discrete CMAC:   => g - 7 epoch -  719   => error -  0.007804932286266553  accuracy -  99.21950677137335
# Discrete CMAC:   => g - 7 epoch -  720   => error -  0.007800097892899149  accuracy -  99.21999021071008
# Discrete CMAC:   => g - 7 epoch -  721   => error -  0.007795275629296605  accuracy -  99.22047243707034
# Discrete CMAC:   => g - 7 epoch -  722   => error -  0.007790465458441531  accuracy -  99.22095345415585
# Discrete CMAC:   => g - 7 epoch -  723   => error -  0.007785667343452207  accuracy -  99.22143326565478
# Discrete CMAC:   => g - 7 epoch -  724   => error -  0.00778088124758225  accuracy -  99.22191187524177
# Discrete CMAC:   => g - 7 epoch -  725   => error -  0.007776107134219834  accuracy -  99.22238928657802
# Discrete CMAC:   => g - 7 epoch -  726   => error -  0.007771344966886917  accuracy -  99.22286550331131
# Discrete CMAC:   => g - 7 epoch -  727   => error -  0.007766594709239127  accuracy -  99.22334052907608
# Discrete CMAC:   => g - 7 epoch -  728   => error -  0.007761856325064653  accuracy -  99.22381436749353
# Discrete CMAC:   => g - 7 epoch -  729   => error -  0.007757129778283689  accuracy -  99.22428702217164
# Discrete CMAC:   => g - 7 epoch -  730   => error -  0.007752415032948545  accuracy -  99.22475849670515
# Discrete CMAC:   => g - 7 epoch -  731   => error -  0.007747712053241984  accuracy -  99.2252287946758
# Discrete CMAC:   => g - 7 epoch -  732   => error -  0.007743020803477441  accuracy -  99.22569791965226
# Discrete CMAC:   => g - 7 epoch -  733   => error -  0.007738341248098135  accuracy -  99.22616587519019
# Discrete CMAC:   => g - 7 epoch -  734   => error -  0.007733673351676629  accuracy -  99.22663266483234
# Discrete CMAC:   => g - 7 epoch -  735   => error -  0.007729017078914047  accuracy -  99.2270982921086
# Discrete CMAC:   => g - 7 epoch -  736   => error -  0.007724372394639634  accuracy -  99.22756276053603
# Discrete CMAC:   => g - 7 epoch -  737   => error -  0.007719739263810199  accuracy -  99.22802607361898
# Discrete CMAC:   => g - 7 epoch -  738   => error -  0.007715117651509562  accuracy -  99.22848823484904
# Discrete CMAC:   => g - 7 epoch -  739   => error -  0.007710507522948107  accuracy -  99.22894924770519
# Discrete CMAC:   => g - 7 epoch -  740   => error -  0.007705908843461673  accuracy -  99.22940911565384
# Discrete CMAC:   => g - 7 epoch -  741   => error -  0.007701321578511777  accuracy -  99.22986784214882
# Discrete CMAC:   => g - 7 epoch -  742   => error -  0.007696745693684615  accuracy -  99.23032543063154
# Discrete CMAC:   => g - 7 epoch -  743   => error -  0.007692181154690503  accuracy -  99.23078188453096
# Discrete CMAC:   => g - 7 epoch -  744   => error -  0.0076876279273635495  accuracy -  99.23123720726365
# Discrete CMAC:   => g - 7 epoch -  745   => error -  0.007683085977660764  accuracy -  99.23169140223392
# Discrete CMAC:   => g - 7 epoch -  746   => error -  0.0076785552716620575  accuracy -  99.2321444728338
# Discrete CMAC:   => g - 7 epoch -  747   => error -  0.007674035775569021  accuracy -  99.2325964224431
# Discrete CMAC:   => g - 7 epoch -  748   => error -  0.007669527455705261  accuracy -  99.23304725442948
# Discrete CMAC:   => g - 7 epoch -  749   => error -  0.007665030278514839  accuracy -  99.23349697214852
# Discrete CMAC:   => g - 7 epoch -  750   => error -  0.007660544210562614  accuracy -  99.23394557894373
# Discrete CMAC:   => g - 7 epoch -  751   => error -  0.007656069218533346  accuracy -  99.23439307814667
# Discrete CMAC:   => g - 7 epoch -  752   => error -  0.007651605269231032  accuracy -  99.2348394730769
# Discrete CMAC:   => g - 7 epoch -  753   => error -  0.007647152329578799  accuracy -  99.23528476704212
# Discrete CMAC:   => g - 7 epoch -  754   => error -  0.0076427103666179  accuracy -  99.2357289633382
# Discrete CMAC:   => g - 7 epoch -  755   => error -  0.007638279347507826  accuracy -  99.23617206524922
# Discrete CMAC:   => g - 7 epoch -  756   => error -  0.007633859239525087  accuracy -  99.23661407604749
# Discrete CMAC:   => g - 7 epoch -  757   => error -  0.00762945001006321  accuracy -  99.23705499899368
# Discrete CMAC:   => g - 7 epoch -  758   => error -  0.007625051626632073  accuracy -  99.2374948373368
# Discrete CMAC:   => g - 7 epoch -  759   => error -  0.007620664056857351  accuracy -  99.23793359431427
# Discrete CMAC:   => g - 7 epoch -  760   => error -  0.007616287268480182  accuracy -  99.23837127315198
# Discrete CMAC:   => g - 7 epoch -  761   => error -  0.007611921229356389  accuracy -  99.23880787706436
# Discrete CMAC:   => g - 7 epoch -  762   => error -  0.00760756590745626  accuracy -  99.23924340925437
# Discrete CMAC:   => g - 7 epoch -  763   => error -  0.007603221270863991  accuracy -  99.2396778729136
# Discrete CMAC:   => g - 7 epoch -  764   => error -  0.007598887287777134  accuracy -  99.24011127122229
# Discrete CMAC:   => g - 7 epoch -  765   => error -  0.007594563926506148  accuracy -  99.24054360734938
# Discrete CMAC:   => g - 7 epoch -  766   => error -  0.007590251155473959  accuracy -  99.2409748844526
# Discrete CMAC:   => g - 7 epoch -  767   => error -  0.007585948943215182  accuracy -  99.24140510567848
# Discrete CMAC:   => g - 7 epoch -  768   => error -  0.007581657258376451  accuracy -  99.24183427416236
# Discrete CMAC:   => g - 7 epoch -  769   => error -  0.0075773760697146475  accuracy -  99.24226239302854
# Discrete CMAC:   => g - 7 epoch -  770   => error -  0.007573105346097897  accuracy -  99.24268946539021
# Discrete CMAC:   => g - 7 epoch -  771   => error -  0.007568845056503903  accuracy -  99.24311549434961
# Discrete CMAC:   => g - 7 epoch -  772   => error -  0.007564595170020061  accuracy -  99.243540482998
# Discrete CMAC:   => g - 7 epoch -  773   => error -  0.007560355655842899  accuracy -  99.24396443441572
# Discrete CMAC:   => g - 7 epoch -  774   => error -  0.0075561264832777475  accuracy -  99.24438735167223
# Discrete CMAC:   => g - 7 epoch -  775   => error -  0.007551907621737963  accuracy -  99.2448092378262
# Discrete CMAC:   => g - 7 epoch -  776   => error -  0.007547699040744704  accuracy -  99.24523009592554
# Discrete CMAC:   => g - 7 epoch -  777   => error -  0.007543500709926376  accuracy -  99.24564992900736
# Discrete CMAC:   => g - 7 epoch -  778   => error -  0.007539312599018189  accuracy -  99.24606874009818
# Discrete CMAC:   => g - 7 epoch -  779   => error -  0.007535134677861821  accuracy -  99.24648653221382
# Discrete CMAC:   => g - 7 epoch -  780   => error -  0.00753096691640498  accuracy -  99.2469033083595
# Discrete CMAC:   => g - 7 epoch -  781   => error -  0.00752680928470062  accuracy -  99.24731907152994
# Discrete CMAC:   => g - 7 epoch -  782   => error -  0.007522661752906945  accuracy -  99.2477338247093
# Discrete CMAC:   => g - 7 epoch -  783   => error -  0.007518524291286632  accuracy -  99.24814757087134
# Discrete CMAC:   => g - 7 epoch -  784   => error -  0.007514396870206608  accuracy -  99.24856031297934
# Discrete CMAC:   => g - 7 epoch -  785   => error -  0.007510279460137492  accuracy -  99.24897205398625
# Discrete CMAC:   => g - 7 epoch -  786   => error -  0.00750617203165338  accuracy -  99.24938279683467
# Discrete CMAC:   => g - 7 epoch -  787   => error -  0.007502074555430949  accuracy -  99.24979254445691
# Discrete CMAC:   => g - 7 epoch -  788   => error -  0.007497987002249462  accuracy -  99.25020129977506
# Discrete CMAC:   => g - 7 epoch -  789   => error -  0.007493909342990324  accuracy -  99.25060906570097
# Discrete CMAC:   => g - 7 epoch -  790   => error -  0.007489841548636411  accuracy -  99.25101584513637
# Discrete CMAC:   => g - 7 epoch -  791   => error -  0.007485783590271633  accuracy -  99.25142164097284
# Discrete CMAC:   => g - 7 epoch -  792   => error -  0.007481735439080817  accuracy -  99.25182645609192
# Discrete CMAC:   => g - 7 epoch -  793   => error -  0.007477697066349043  accuracy -  99.2522302933651
# Discrete CMAC:   => g - 7 epoch -  794   => error -  0.007473668443461534  accuracy -  99.25263315565385
# Discrete CMAC:   => g - 7 epoch -  795   => error -  0.0074696495419027675  accuracy -  99.25303504580972
# Discrete CMAC:   => g - 7 epoch -  796   => error -  0.0074656403332562515  accuracy -  99.25343596667437
# Discrete CMAC:   => g - 7 epoch -  797   => error -  0.007461640789204416  accuracy -  99.25383592107956
# Discrete CMAC:   => g - 7 epoch -  798   => error -  0.007457650881527722  accuracy -  99.25423491184723
# Discrete CMAC:   => g - 7 epoch -  799   => error -  0.007453670582104777  accuracy -  99.25463294178952
# Discrete CMAC:   => g - 7 epoch -  800   => error -  0.007449699862911441  accuracy -  99.25503001370886
# Discrete CMAC:   => g - 7 epoch -  801   => error -  0.0074457386960206096  accuracy -  99.25542613039794
# Discrete CMAC:   => g - 7 epoch -  802   => error -  0.0074417870536021  accuracy -  99.25582129463979
# Discrete CMAC:   => g - 7 epoch -  803   => error -  0.0074378449079217646  accuracy -  99.25621550920782
# Discrete CMAC:   => g - 7 epoch -  804   => error -  0.0074339122313412664  accuracy -  99.25660877686587
# Discrete CMAC:   => g - 7 epoch -  805   => error -  0.007429988996317971  accuracy -  99.2570011003682
# Discrete CMAC:   => g - 7 epoch -  806   => error -  0.007426075175404279  accuracy -  99.25739248245958
# Discrete CMAC:   => g - 7 epoch -  807   => error -  0.0074221707412472915  accuracy -  99.25778292587528
# Discrete CMAC:   => g - 7 epoch -  808   => error -  0.007418275666588148  accuracy -  99.25817243334119
# Discrete CMAC:   => g - 7 epoch -  809   => error -  0.0074143899242623545  accuracy -  99.25856100757376
# Discrete CMAC:   => g - 7 epoch -  810   => error -  0.007410513487198678  accuracy -  99.25894865128014
# Discrete CMAC:   => g - 7 epoch -  811   => error -  0.007406646328419031  accuracy -  99.2593353671581
# Discrete CMAC:   => g - 7 epoch -  812   => error -  0.007402788421038364  accuracy -  99.25972115789617
# Discrete CMAC:   => g - 7 epoch -  813   => error -  0.007398939738263888  accuracy -  99.26010602617362
# Discrete CMAC:   => g - 7 epoch -  814   => error -  0.007395100253394626  accuracy -  99.26048997466054
# Discrete CMAC:   => g - 7 epoch -  815   => error -  0.007391269939821532  accuracy -  99.26087300601785
# Discrete CMAC:   => g - 7 epoch -  816   => error -  0.007387448771026817  accuracy -  99.26125512289732
# Discrete CMAC:   => g - 7 epoch -  817   => error -  0.0073836367205835085  accuracy -  99.26163632794164
# Discrete CMAC:   => g - 7 epoch -  818   => error -  0.007379833762155341  accuracy -  99.26201662378446
# Discrete CMAC:   => g - 7 epoch -  819   => error -  0.007376039869495865  accuracy -  99.26239601305042
# Discrete CMAC:   => g - 7 epoch -  820   => error -  0.007372255016448892  accuracy -  99.26277449835511
# Discrete CMAC:   => g - 7 epoch -  821   => error -  0.0073684791769474955  accuracy -  99.26315208230525
# Discrete CMAC:   => g - 7 epoch -  822   => error -  0.007364712325013678  accuracy -  99.26352876749863
# Discrete CMAC:   => g - 7 epoch -  823   => error -  0.007360954434758371  accuracy -  99.26390455652417
# Discrete CMAC:   => g - 7 epoch -  824   => error -  0.0073572054803809905  accuracy -  99.2642794519619
# Discrete CMAC:   => g - 7 epoch -  825   => error -  0.007353465436168549  accuracy -  99.26465345638314
# Discrete CMAC:   => g - 7 epoch -  826   => error -  0.0073497342764962115  accuracy -  99.26502657235038
# Discrete CMAC:   => g - 7 epoch -  827   => error -  0.007346011975826183  accuracy -  99.26539880241738
# Discrete CMAC:   => g - 7 epoch -  828   => error -  0.00734229850870749  accuracy -  99.26577014912925
# Discrete CMAC:   => g - 7 epoch -  829   => error -  0.007338593849776198  accuracy -  99.26614061502238
# Discrete CMAC:   => g - 7 epoch -  830   => error -  0.007334897973754306  accuracy -  99.26651020262457
# Discrete CMAC:   => g - 7 epoch -  831   => error -  0.0073312108554497435  accuracy -  99.26687891445502
# Discrete CMAC:   => g - 7 epoch -  832   => error -  0.007327532469756148  accuracy -  99.26724675302438
# Discrete CMAC:   => g - 7 epoch -  833   => error -  0.007323862791652314  accuracy -  99.26761372083477
# Discrete CMAC:   => g - 7 epoch -  834   => error -  0.007320201796201964  accuracy -  99.26797982037981
# Discrete CMAC:   => g - 7 epoch -  835   => error -  0.007316549458553312  accuracy -  99.26834505414467
# Discrete CMAC:   => g - 7 epoch -  836   => error -  0.0073129057539389475  accuracy -  99.2687094246061
# Discrete CMAC:   => g - 7 epoch -  837   => error -  0.00730927065767506  accuracy -  99.2690729342325
# Discrete CMAC:   => g - 7 epoch -  838   => error -  0.0073056441451617715  accuracy -  99.26943558548382
# Discrete CMAC:   => g - 7 epoch -  839   => error -  0.007302026191881916  accuracy -  99.26979738081181
# Discrete CMAC:   => g - 7 epoch -  840   => error -  0.007298416773401706  accuracy -  99.27015832265982
# Discrete CMAC:   => g - 7 epoch -  841   => error -  0.007294815865369619  accuracy -  99.27051841346304
# Discrete CMAC:   => g - 7 epoch -  842   => error -  0.007291223443516515  accuracy -  99.27087765564835
# Discrete CMAC:   => g - 7 epoch -  843   => error -  0.007287639483654851  accuracy -  99.27123605163452
# Discrete CMAC:   => g - 7 epoch -  844   => error -  0.0072840639616791325  accuracy -  99.27159360383209
# Discrete CMAC:   => g - 7 epoch -  845   => error -  0.0072804968535646886  accuracy -  99.27195031464353
# Discrete CMAC:   => g - 7 epoch -  846   => error -  0.007276938135368005  accuracy -  99.2723061864632
# Discrete CMAC:   => g - 7 epoch -  847   => error -  0.007273387783226171  accuracy -  99.27266122167738
# Discrete CMAC:   => g - 7 epoch -  848   => error -  0.0072698457733565425  accuracy -  99.27301542266434
# Discrete CMAC:   => g - 7 epoch -  849   => error -  0.007266312082056303  accuracy -  99.27336879179437
# Discrete CMAC:   => g - 7 epoch -  850   => error -  0.007262786685702571  accuracy -  99.27372133142974
# Discrete CMAC:   => g - 7 epoch -  851   => error -  0.0072592695607516244  accuracy -  99.27407304392484
# Discrete CMAC:   => g - 7 epoch -  852   => error -  0.007255760683738677  accuracy -  99.27442393162613
# Discrete CMAC:   => g - 7 epoch -  853   => error -  0.007252260031278102  accuracy -  99.27477399687218
# Discrete CMAC:   => g - 7 epoch -  854   => error -  0.007248767580062099  accuracy -  99.2751232419938
# Discrete CMAC:   => g - 7 epoch -  855   => error -  0.007245283306861472  accuracy -  99.27547166931386
# Discrete CMAC:   => g - 7 epoch -  856   => error -  0.007241807188524518  accuracy -  99.27581928114755
# Discrete CMAC:   => g - 7 epoch -  857   => error -  0.00723833920197714  accuracy -  99.27616607980228
# Discrete CMAC:   => g - 7 epoch -  858   => error -  0.0072348793242223985  accuracy -  99.27651206757776
# Discrete CMAC:   => g - 7 epoch -  859   => error -  0.0072314275323402954  accuracy -  99.27685724676597
# Discrete CMAC:   => g - 7 epoch -  860   => error -  0.007227983803487326  accuracy -  99.27720161965127
# Discrete CMAC:   => g - 7 epoch -  861   => error -  0.0072245481148963675  accuracy -  99.27754518851036
# Discrete CMAC:   => g - 7 epoch -  862   => error -  0.007221120443876239  accuracy -  99.27788795561237
# Discrete CMAC:   => g - 7 epoch -  863   => error -  0.007217700767811475  accuracy -  99.27822992321886
# Discrete CMAC:   => g - 7 epoch -  864   => error -  0.007214289064161883  accuracy -  99.2785710935838
# Discrete CMAC:   => g - 7 epoch -  865   => error -  0.007210885310462656  accuracy -  99.27891146895374
# Discrete CMAC:   => g - 7 epoch -  866   => error -  0.007207489484323482  accuracy -  99.27925105156766
# Discrete CMAC:   => g - 7 epoch -  867   => error -  0.007204101563428766  accuracy -  99.27958984365712
# Discrete CMAC:   => g - 7 epoch -  868   => error -  0.007200721525537079  accuracy -  99.27992784744629
# Discrete CMAC:   => g - 7 epoch -  869   => error -  0.00719734934848093  accuracy -  99.28026506515191
# Discrete CMAC:   => g - 7 epoch -  870   => error -  0.007193985010166548  accuracy -  99.28060149898334
# Discrete CMAC:   => g - 7 epoch -  871   => error -  0.007190628488573214  accuracy -  99.28093715114268
# Discrete CMAC:   => g - 7 epoch -  872   => error -  0.0071872797617538176  accuracy -  99.28127202382461
# Discrete CMAC:   => g - 7 epoch -  873   => error -  0.007183938807833634  accuracy -  99.28160611921663
# Discrete CMAC:   => g - 7 epoch -  874   => error -  0.007180605605010659  accuracy -  99.28193943949893
# Discrete CMAC:   => g - 7 epoch -  875   => error -  0.007177280131555053  accuracy -  99.28227198684449
# Discrete CMAC:   => g - 7 epoch -  876   => error -  0.007173962365808806  accuracy -  99.28260376341912
# Discrete CMAC:   => g - 7 epoch -  877   => error -  0.007170652286185852  accuracy -  99.28293477138142
# Discrete CMAC:   => g - 7 epoch -  878   => error -  0.007167349871171402  accuracy -  99.28326501288286
# Discrete CMAC:   => g - 7 epoch -  879   => error -  0.007164055099321609  accuracy -  99.28359449006784
# Discrete CMAC:   => g - 7 epoch -  880   => error -  0.007160767949263902  accuracy -  99.2839232050736
# Discrete CMAC:   => g - 7 epoch -  881   => error -  0.007157488399695766  accuracy -  99.28425116003042
# Discrete CMAC:   => g - 7 epoch -  882   => error -  0.007154216429385518  accuracy -  99.28457835706145
# Discrete CMAC:   => g - 7 epoch -  883   => error -  0.007150952017171086  accuracy -  99.2849047982829
# Discrete CMAC:   => g - 7 epoch -  884   => error -  0.007147695141960342  accuracy -  99.28523048580396
# Discrete CMAC:   => g - 7 epoch -  885   => error -  0.007144445782730657  accuracy -  99.28555542172694
# Discrete CMAC:   => g - 7 epoch -  886   => error -  0.007141203918528571  accuracy -  99.28587960814714
# Discrete CMAC:   => g - 7 epoch -  887   => error -  0.00713796952846979  accuracy -  99.28620304715302
# Discrete CMAC:   => g - 7 epoch -  888   => error -  0.007134742591738519  accuracy -  99.28652574082615
# Discrete CMAC:   => g - 7 epoch -  889   => error -  0.007131523087587355  accuracy -  99.28684769124126
# Discrete CMAC:   => g - 7 epoch -  890   => error -  0.007128310995337173  accuracy -  99.28716890046628
# Discrete CMAC:   => g - 7 epoch -  891   => error -  0.007125106294376793  accuracy -  99.28748937056233
# Discrete CMAC:   => g - 7 epoch -  892   => error -  0.007121908964162649  accuracy -  99.28780910358374
# Discrete CMAC:   => g - 7 epoch -  893   => error -  0.007118718984218564  accuracy -  99.28812810157814
# Discrete CMAC:   => g - 7 epoch -  894   => error -  0.0071155363341355304  accuracy -  99.28844636658644
# Discrete CMAC:   => g - 7 epoch -  895   => error -  0.007112360993571265  accuracy -  99.28876390064288
# Discrete CMAC:   => g - 7 epoch -  896   => error -  0.007109192942250431  accuracy -  99.28908070577495
# Discrete CMAC:   => g - 7 epoch -  897   => error -  0.007106032159963749  accuracy -  99.28939678400363
# Discrete CMAC:   => g - 7 epoch -  898   => error -  0.00710287862656811  accuracy -  99.28971213734319
# Discrete CMAC:   => g - 7 epoch -  899   => error -  0.007099732321986574  accuracy -  99.29002676780134
# Discrete CMAC:   => g - 7 epoch -  900   => error -  0.0070965932262073705  accuracy -  99.29034067737926
# Discrete CMAC:   => g - 7 epoch -  901   => error -  0.007093461319284344  accuracy -  99.29065386807156
# Discrete CMAC:   => g - 7 epoch -  902   => error -  0.007090336581336398  accuracy -  99.29096634186637
# Discrete CMAC:   => g - 7 epoch -  903   => error -  0.007087218992547495  accuracy -  99.29127810074525
# Discrete CMAC:   => g - 7 epoch -  904   => error -  0.007084108533165989  accuracy -  99.2915891466834
# Discrete CMAC:   => g - 7 epoch -  905   => error -  0.0070810051835045185  accuracy -  99.29189948164955
# Discrete CMAC:   => g - 7 epoch -  906   => error -  0.007077908923940224  accuracy -  99.29220910760598
# Discrete CMAC:   => g - 7 epoch -  907   => error -  0.007074819734913751  accuracy -  99.29251802650863
# Discrete CMAC:   => g - 7 epoch -  908   => error -  0.007071737596929806  accuracy -  99.29282624030702
# Discrete CMAC:   => g - 7 epoch -  909   => error -  0.0070686624905560436  accuracy -  99.29313375094439
# Discrete CMAC:   => g - 7 epoch -  910   => error -  0.0070655943964236245  accuracy -  99.29344056035764
# Discrete CMAC:   => g - 7 epoch -  911   => error -  0.007062533295226547  accuracy -  99.29374667047735
# Discrete CMAC:   => g - 7 epoch -  912   => error -  0.0070594791677215385  accuracy -  99.29405208322784
# Discrete CMAC:   => g - 7 epoch -  913   => error -  0.007056431994727497  accuracy -  99.29435680052725
# Discrete CMAC:   => g - 7 epoch -  914   => error -  0.0070533917571261595  accuracy -  99.29466082428739
# Discrete CMAC:   => g - 7 epoch -  915   => error -  0.007050358435860549  accuracy -  99.29496415641394
# Discrete CMAC:   => g - 7 epoch -  916   => error -  0.0070473320119358585  accuracy -  99.29526679880641
# Discrete CMAC:   => g - 7 epoch -  917   => error -  0.0070443124664186785  accuracy -  99.29556875335813
# Discrete CMAC:   => g - 7 epoch -  918   => error -  0.007041299780436994  accuracy -  99.2958700219563
# Discrete CMAC:   => g - 7 epoch -  919   => error -  0.007038293935179629  accuracy -  99.29617060648204
# Discrete CMAC:   => g - 7 epoch -  920   => error -  0.0070352949118964725  accuracy -  99.29647050881036
# Discrete CMAC:   => g - 7 epoch -  921   => error -  0.007032302691897918  accuracy -  99.29676973081021
# Discrete CMAC:   => g - 7 epoch -  922   => error -  0.007029317256554646  accuracy -  99.29706827434454
# Discrete CMAC:   => g - 7 epoch -  923   => error -  0.00702633858729762  accuracy -  99.29736614127023
# Discrete CMAC:   => g - 7 epoch -  924   => error -  0.0070233666656176474  accuracy -  99.29766333343824
# Discrete CMAC:   => g - 7 epoch -  925   => error -  0.007020401473065263  accuracy -  99.29795985269348
# Discrete CMAC:   => g - 7 epoch -  926   => error -  0.0070174429912504  accuracy -  99.29825570087496
# Discrete CMAC:   => g - 7 epoch -  927   => error -  0.007014491201842388  accuracy -  99.29855087981576
# Discrete CMAC:   => g - 7 epoch -  928   => error -  0.007011546086569398  accuracy -  99.29884539134306
# Discrete CMAC:   => g - 7 epoch -  929   => error -  0.007008607627218555  accuracy -  99.29913923727814
# Discrete CMAC:   => g - 7 epoch -  930   => error -  0.007005675805635492  accuracy -  99.29943241943646
# Discrete CMAC:   => g - 7 epoch -  931   => error -  0.00700275060372435  accuracy -  99.29972493962757
# ...
# Continuous CMAC:   => g - 7 epoch -  2195   => error -  0.005363382884253531  accuracy -  99.46366171157464
# Continuous CMAC:   => g - 7 epoch -  2196   => error -  0.005363214981484399  accuracy -  99.46367850185156
# Continuous CMAC:   => g - 7 epoch -  2197   => error -  0.005363047332528015  accuracy -  99.4636952667472
# Continuous CMAC:   => g - 7 epoch -  2198   => error -  0.005362879937125586  accuracy -  99.46371200628744
# Continuous CMAC:   => g - 7 epoch -  2199   => error -  0.00536271279501932  accuracy -  99.46372872049807
# Continuous CMAC:   => g - 7 epoch -  2200   => error -  0.00536254590595131  accuracy -  99.46374540940486
# Continuous CMAC:   => g - 7 epoch -  2201   => error -  0.005362379269664097  accuracy -  99.46376207303359
# Continuous CMAC:   => g - 7 epoch -  2202   => error -  0.0053622128859006635  accuracy -  99.46377871140993
# Continuous CMAC:   => g - 7 epoch -  2203   => error -  0.005362046754404326  accuracy -  99.46379532455957
# Continuous CMAC:   => g - 7 epoch -  2204   => error -  0.005361880874918623  accuracy -  99.46381191250813
# Continuous CMAC:   => g - 7 epoch -  2205   => error -  0.005361715247187537  accuracy -  99.46382847528125
# Continuous CMAC:   => g - 7 epoch -  2206   => error -  0.005361549870955384  accuracy -  99.46384501290446
# Continuous CMAC:   => g - 7 epoch -  2207   => error -  0.005361384745966813  accuracy -  99.46386152540332
# Continuous CMAC:   => g - 7 epoch -  2208   => error -  0.005361219871966916  accuracy -  99.4638780128033
# Continuous CMAC:   => g - 7 epoch -  2209   => error -  0.005361055248700786  accuracy -  99.46389447512992
# Continuous CMAC:   => g - 7 epoch -  2210   => error -  0.005360890875914404  accuracy -  99.46391091240856
# Continuous CMAC:   => g - 7 epoch -  2211   => error -  0.0053607267533535286  accuracy -  99.46392732466465
# Continuous CMAC:   => g - 7 epoch -  2212   => error -  0.0053605628807645855  accuracy -  99.46394371192355
# Continuous CMAC:   => g - 7 epoch -  2213   => error -  0.005360399257894444  accuracy -  99.46396007421056
# Continuous CMAC:   => g - 7 epoch -  2214   => error -  0.005360235884489861  accuracy -  99.46397641155102
# Continuous CMAC:   => g - 7 epoch -  2215   => error -  0.005360072760298373  accuracy -  99.46399272397016
# Continuous CMAC:   => g - 7 epoch -  2216   => error -  0.005359909885067737  accuracy -  99.46400901149323
# Continuous CMAC:   => g - 7 epoch -  2217   => error -  0.005359747258545822  accuracy -  99.46402527414541
# Continuous CMAC:   => g - 7 epoch -  2218   => error -  0.005359584880481161  accuracy -  99.46404151195189
# Continuous CMAC:   => g - 7 epoch -  2219   => error -  0.005359422750622511  accuracy -  99.46405772493775
# Continuous CMAC:   => g - 7 epoch -  2220   => error -  0.00535926086871874  accuracy -  99.46407391312813
# Continuous CMAC:   => g - 7 epoch -  2221   => error -  0.005359099234519382  accuracy -  99.46409007654806
# Continuous CMAC:   => g - 7 epoch -  2222   => error -  0.005358937847774192  accuracy -  99.46410621522259
# Continuous CMAC:   => g - 7 epoch -  2223   => error -  0.005358776708233037  accuracy -  99.46412232917669
# Continuous CMAC:   => g - 7 epoch -  2224   => error -  0.005358615815646561  accuracy -  99.46413841843534
# Continuous CMAC:   => g - 7 epoch -  2225   => error -  0.005358455169765297  accuracy -  99.46415448302346
# Continuous CMAC:   => g - 7 epoch -  2226   => error -  0.005358294770340444  accuracy -  99.46417052296596
# Continuous CMAC:   => g - 7 epoch -  2227   => error -  0.0053581346171232  accuracy -  99.46418653828768
# Continuous CMAC:   => g - 7 epoch -  2228   => error -  0.005357974709865543  accuracy -  99.46420252901345
# Continuous CMAC:   => g - 7 epoch -  2229   => error -  0.0053578150483193365  accuracy -  99.46421849516807
# Continuous CMAC:   => g - 7 epoch -  2230   => error -  0.005357655632237113  accuracy -  99.4642344367763
# Continuous CMAC:   => g - 7 epoch -  2231   => error -  0.005357496461371403  accuracy -  99.46425035386287
# Continuous CMAC:   => g - 7 epoch -  2232   => error -  0.005357337535475404  accuracy -  99.46426624645245
# Continuous CMAC:   => g - 7 epoch -  2233   => error -  0.005357178854302425  accuracy -  99.46428211456976
# Continuous CMAC:   => g - 7 epoch -  2234   => error -  0.0053570204176061065  accuracy -  99.46429795823938
# Continuous CMAC:   => g - 7 epoch -  2235   => error -  0.005356862225140535  accuracy -  99.46431377748594
# Continuous CMAC:   => g - 7 epoch -  2236   => error -  0.005356704276660129  accuracy -  99.46432957233398
# Continuous CMAC:   => g - 7 epoch -  2237   => error -  0.005356546571919529  accuracy -  99.46434534280804
# Continuous CMAC:   => g - 7 epoch -  2238   => error -  0.005356389110673709  accuracy -  99.46436108893263
# Continuous CMAC:   => g - 7 epoch -  2239   => error -  0.005356231892677976  accuracy -  99.4643768107322
# Continuous CMAC:   => g - 7 epoch -  2240   => error -  0.00535607491768797  accuracy -  99.4643925082312
# Continuous CMAC:   => g - 7 epoch -  2241   => error -  0.005355918185459774  accuracy -  99.46440818145402
# Continuous CMAC:   => g - 7 epoch -  2242   => error -  0.0053557616957496945  accuracy -  99.46442383042503
# Continuous CMAC:   => g - 7 epoch -  2243   => error -  0.005355605448314371  accuracy -  99.46443945516856
# Continuous CMAC:   => g - 7 epoch -  2244   => error -  0.005355449442910554  accuracy -  99.46445505570894
# Continuous CMAC:   => g - 7 epoch -  2245   => error -  0.0053552936792957695  accuracy -  99.46447063207043
# Continuous CMAC:   => g - 7 epoch -  2246   => error -  0.005355138157227435  accuracy -  99.46448618427726
# Continuous CMAC:   => g - 7 epoch -  2247   => error -  0.005354982876463632  accuracy -  99.46450171235364
# Continuous CMAC:   => g - 7 epoch -  2248   => error -  0.0053548278367624436  accuracy -  99.46451721632376
# Continuous CMAC:   => g - 7 epoch -  2249   => error -  0.005354673037882507  accuracy -  99.46453269621175
# Continuous CMAC:   => g - 7 epoch -  2250   => error -  0.005354518479582682  accuracy -  99.46454815204173
# Continuous CMAC:   => g - 7 epoch -  2251   => error -  0.0053543641616221604  accuracy -  99.46456358383779
# Continuous CMAC:   => g - 7 epoch -  2252   => error -  0.00535421008376058  accuracy -  99.46457899162394
# Continuous CMAC:   => g - 7 epoch -  2253   => error -  0.005354056245757577  accuracy -  99.46459437542424
# Continuous CMAC:   => g - 7 epoch -  2254   => error -  0.005353902647373454  accuracy -  99.46460973526266
# Continuous CMAC:   => g - 7 epoch -  2255   => error -  0.0053537492883686255  accuracy -  99.46462507116314
# Continuous CMAC:   => g - 7 epoch -  2256   => error -  0.005353596168503949  accuracy -  99.4646403831496
# Continuous CMAC:   => g - 7 epoch -  2257   => error -  0.005353443287540394  accuracy -  99.46465567124596
# Continuous CMAC:   => g - 7 epoch -  2258   => error -  0.0053532906452394835  accuracy -  99.46467093547605
# Continuous CMAC:   => g - 7 epoch -  2259   => error -  0.005353138241362965  accuracy -  99.4646861758637
# Continuous CMAC:   => g - 7 epoch -  2260   => error -  0.005352986075672805  accuracy -  99.46470139243272
# Continuous CMAC:   => g - 7 epoch -  2261   => error -  0.005352834147931529  accuracy -  99.46471658520684
# Continuous CMAC:   => g - 7 epoch -  2262   => error -  0.0053526824579015475  accuracy -  99.46473175420985
# Continuous CMAC:   => g - 7 epoch -  2263   => error -  0.005352531005346162  accuracy -  99.46474689946538
# Continuous CMAC:   => g - 7 epoch -  2264   => error -  0.00535237979002845  accuracy -  99.46476202099716
# Continuous CMAC:   => g - 7 epoch -  2265   => error -  0.005352228811712156  accuracy -  99.46477711882878
# Continuous CMAC:   => g - 7 epoch -  2266   => error -  0.005352078070161137  accuracy -  99.4647921929839
# Continuous CMAC:   => g - 7 epoch -  2267   => error -  0.005351927565139691  accuracy -  99.46480724348604
# Continuous CMAC:   => g - 7 epoch -  2268   => error -  0.005351777296412452  accuracy -  99.46482227035875
# Continuous CMAC:   => g - 7 epoch -  2269   => error -  0.005351627263744052  accuracy -  99.46483727362559
# Continuous CMAC:   => g - 7 epoch -  2270   => error -  0.005351477466899901  accuracy -  99.46485225331001
# Continuous CMAC:   => g - 7 epoch -  2271   => error -  0.005351327905645298  accuracy -  99.46486720943547
# Continuous CMAC:   => g - 7 epoch -  2272   => error -  0.0053511785797462075  accuracy -  99.46488214202537
# Continuous CMAC:   => g - 7 epoch -  2273   => error -  0.005351029488968595  accuracy -  99.46489705110314
# Continuous CMAC:   => g - 7 epoch -  2274   => error -  0.00535088063307898  accuracy -  99.4649119366921
# Continuous CMAC:   => g - 7 epoch -  2275   => error -  0.005350732011843995  accuracy -  99.4649267988156
# Continuous CMAC:   => g - 7 epoch -  2276   => error -  0.005350583625030714  accuracy -  99.46494163749693
# Continuous CMAC:   => g - 7 epoch -  2277   => error -  0.005350435472406434  accuracy -  99.46495645275935
# Continuous CMAC:   => g - 7 epoch -  2278   => error -  0.005350287553738897  accuracy -  99.46497124462611
# Continuous CMAC:   => g - 7 epoch -  2279   => error -  0.005350139868795845  accuracy -  99.46498601312041
# Continuous CMAC:   => g - 7 epoch -  2280   => error -  0.005349992417345684  accuracy -  99.46500075826543
# Continuous CMAC:   => g - 7 epoch -  2281   => error -  0.005349845199157044  accuracy -  99.46501548008429
# Continuous CMAC:   => g - 7 epoch -  2282   => error -  0.005349698213998555  accuracy -  99.46503017860014
# Continuous CMAC:   => g - 7 epoch -  2283   => error -  0.005349551461639623  accuracy -  99.46504485383603
# Continuous CMAC:   => g - 7 epoch -  2284   => error -  0.005349404941849434  accuracy -  99.46505950581506
# Continuous CMAC:   => g - 7 epoch -  2285   => error -  0.005349258654398059  accuracy -  99.4650741345602
# Continuous CMAC:   => g - 7 epoch -  2286   => error -  0.005349112599055461  accuracy -  99.46508874009446
# Continuous CMAC:   => g - 7 epoch -  2287   => error -  0.0053489667755919346  accuracy -  99.46510332244081
# Continuous CMAC:   => g - 7 epoch -  2288   => error -  0.0053488211837782185  accuracy -  99.46511788162218
# Continuous CMAC:   => g - 7 epoch -  2289   => error -  0.005348675823385274  accuracy -  99.46513241766148
# Continuous CMAC:   => g - 7 epoch -  2290   => error -  0.005348530694184395  accuracy -  99.46514693058155
# Continuous CMAC:   => g - 7 epoch -  2291   => error -  0.005348385795947208  accuracy -  99.46516142040528
# Continuous CMAC:   => g - 7 epoch -  2292   => error -  0.005348241128445452  accuracy -  99.46517588715545
# Continuous CMAC:   => g - 7 epoch -  2293   => error -  0.0053480966914514205  accuracy -  99.46519033085485
# Continuous CMAC:   => g - 7 epoch -  2294   => error -  0.005347952484737628  accuracy -  99.46520475152624
# Continuous CMAC:   => g - 7 epoch -  2295   => error -  0.005347808508076812  accuracy -  99.46521914919232
# Continuous CMAC:   => g - 7 epoch -  2296   => error -  0.005347664761242044  accuracy -  99.4652335238758
# Continuous CMAC:   => g - 7 epoch -  2297   => error -  0.0053475212440066144  accuracy -  99.46524787559935
# Continuous CMAC:   => g - 7 epoch -  2298   => error -  0.005347377956144261  accuracy -  99.46526220438557
# Continuous CMAC:   => g - 7 epoch -  2299   => error -  0.005347234897429054  accuracy -  99.4652765102571
# Continuous CMAC:   => g - 7 epoch -  2300   => error -  0.005347092067635062  accuracy -  99.46529079323649
# Continuous CMAC:   => g - 7 epoch -  2301   => error -  0.005346949466537021  accuracy -  99.4653050533463
# Continuous CMAC:   => g - 7 epoch -  2302   => error -  0.005346807093909667  accuracy -  99.46531929060903
# Continuous CMAC:   => g - 7 epoch -  2303   => error -  0.005346664949528179  accuracy -  99.46533350504718
# Continuous CMAC:   => g - 7 epoch -  2304   => error -  0.00534652303316796  accuracy -  99.46534769668321
# Continuous CMAC:   => g - 7 epoch -  2305   => error -  0.005346381344604856  accuracy -  99.46536186553952
# Continuous CMAC:   => g - 7 epoch -  2306   => error -  0.005346239883614823  accuracy -  99.46537601163851
# Continuous CMAC:   => g - 7 epoch -  2307   => error -  0.005346098649974151  accuracy -  99.46539013500258
# Continuous CMAC:   => g - 7 epoch -  2308   => error -  0.005345957643459576  accuracy -  99.46540423565405
# Continuous CMAC:   => g - 7 epoch -  2309   => error -  0.005345816863847941  accuracy -  99.4654183136152
# Continuous CMAC:   => g - 7 epoch -  2310   => error -  0.005345676310916425  accuracy -  99.46543236890835
# Continuous CMAC:   => g - 7 epoch -  2311   => error -  0.00534553598444254  accuracy -  99.46544640155575
# Continuous CMAC:   => g - 7 epoch -  2312   => error -  0.005345395884204018  accuracy -  99.4654604115796
# Continuous CMAC:   => g - 7 epoch -  2313   => error -  0.005345256009979038  accuracy -  99.46547439900209
# Continuous CMAC:   => g - 7 epoch -  2314   => error -  0.0053451163615459985  accuracy -  99.4654883638454
# Continuous CMAC:   => g - 7 epoch -  2315   => error -  0.00534497693868341  accuracy -  99.46550230613165
# Continuous CMAC:   => g - 7 epoch -  2316   => error -  0.0053448377411702275  accuracy -  99.46551622588298
# Continuous CMAC:   => g - 7 epoch -  2317   => error -  0.005344698768785849  accuracy -  99.46553012312141
# Continuous CMAC:   => g - 7 epoch -  2318   => error -  0.0053445600213096744  accuracy -  99.46554399786903
# Continuous CMAC:   => g - 7 epoch -  2319   => error -  0.0053444214985214344  accuracy -  99.46555785014786
# Continuous CMAC:   => g - 7 epoch -  2320   => error -  0.005344283200201416  accuracy -  99.46557167997986
# Continuous CMAC:   => g - 7 epoch -  2321   => error -  0.005344145126129796  accuracy -  99.46558548738702
# Continuous CMAC:   => g - 7 epoch -  2322   => error -  0.005344007276087415  accuracy -  99.46559927239126
# Continuous CMAC:   => g - 7 epoch -  2323   => error -  0.005343869649855226  accuracy -  99.46561303501447
# Continuous CMAC:   => g - 7 epoch -  2324   => error -  0.0053437322472142945  accuracy -  99.46562677527857
# Continuous CMAC:   => g - 7 epoch -  2325   => error -  0.0053435950679463495  accuracy -  99.46564049320537
# Continuous CMAC:   => g - 7 epoch -  2326   => error -  0.0053434581118331215  accuracy -  99.46565418881669
# Continuous CMAC:   => g - 7 epoch -  2327   => error -  0.005343321378656785  accuracy -  99.46566786213432
# Continuous CMAC:   => g - 7 epoch -  2328   => error -  0.005343184868199624  accuracy -  99.46568151318004
# Continuous CMAC:   => g - 7 epoch -  2329   => error -  0.0053430485802442584  accuracy -  99.46569514197557
# Continuous CMAC:   => g - 7 epoch -  2330   => error -  0.00534291251457375  accuracy -  99.46570874854262
# Continuous CMAC:   => g - 7 epoch -  2331   => error -  0.005342776670971383  accuracy -  99.46572233290286
# Continuous CMAC:   => g - 7 epoch -  2332   => error -  0.005342641049220553  accuracy -  99.46573589507794
# Continuous CMAC:   => g - 7 epoch -  2333   => error -  0.0053425056491051  accuracy -  99.46574943508949
# Continuous CMAC:   => g - 7 epoch -  2334   => error -  0.005342370470409086  accuracy -  99.4657629529591
# Continuous CMAC:   => g - 7 epoch -  2335   => error -  0.005342235512916793  accuracy -  99.46577644870833
# Continuous CMAC:   => g - 7 epoch -  2336   => error -  0.005342100776413061  accuracy -  99.4657899223587
# Continuous CMAC:   => g - 7 epoch -  2337   => error -  0.005341966260682729  accuracy -  99.46580337393172
# Continuous CMAC:   => g - 7 epoch -  2338   => error -  0.005341831965510968  accuracy -  99.4658168034489
# Continuous CMAC:   => g - 7 epoch -  2339   => error -  0.0053416978906832835  accuracy -  99.46583021093167
# Continuous CMAC:   => g - 7 epoch -  2340   => error -  0.005341564035985402  accuracy -  99.46584359640146
# Continuous CMAC:   => g - 7 epoch -  2341   => error -  0.005341430401203384  accuracy -  99.46585695987966
# Continuous CMAC:   => g - 7 epoch -  2342   => error -  0.0053412969861235116  accuracy -  99.46587030138765

# %% [markdown]
# 3. Discuss how you might use recurrent connections to train a CMAC to output
# a desired trajectory without using time as an input (e.g., state only). You may earn
# up to 5 extra homework points if you implement your idea and show that it
# works.

# %% [markdown]
# Framework for recurrent Neural Network (RNN)
# 1. Initialize weight matrices U, V, W from random distribution and bias b, c with zeros
# 2. Forward propagation to compute predictions
# 3. Compute the loss
# 4. Back-propagation to compute gradients
# 5. Update weights based on gradients
# 6. Repeat steps 2–5
#
# The below is code for predicting words based on a couple sentences.

# %%
# Class for Recurrent Neural Network
import numpy as np

class RNN:
    def __init__(self, hidden_size, vocab_size, seq_length, learning_rate):
        # hyper parameters
        self.hidden_size = hidden_size
        self.vocab_size = vocab_size
        self.seq_length = seq_length
        self.learning_rate = learning_rate
        # model parameters
        self.U = np.random.uniform(-np.sqrt(1./vocab_size), np.sqrt(1./vocab_size), (hidden_size, vocab_size))
        self.V = np.random.uniform(-np.sqrt(1./hidden_size), np.sqrt(1./hidden_size), (vocab_size, hidden_size))
        self.W = np.random.uniform(-np.sqrt(1./hidden_size), np.sqrt(1./hidden_size), (hidden_size, hidden_size))
        self.b = np.zeros((hidden_size, 1)) # bias for hidden layer
        self.c = np.zeros((vocab_size, 1)) # bias for output
        
        # memory vars
        self.mU = np.zeros_like(self.U)
        self.mW = np.zeros_like(self.W)
        self.mV = np.zeros_like(self.V)
        self.mb = np.zeros_like(self.b)
        self.mc = np.zeros_like(self.c)

    #probability of next character (like chatGPT)
    def softmax(self, x):
        p = np.exp(x- np.max(x))
        return p / np.sum(p)
        
    def forward(self, inputs, hprev):
            xs, hs, os, ycap = {}, {}, {}, {}
            hs[-1] = np.copy(hprev)
            for t in range(len(inputs)):
                xs[t] = np.zeros((self.vocab_size,1))
                xs[t][inputs[t]] = 1 # one hot encoding , 1-of-k
                hs[t] = np.tanh(np.dot(self.U,xs[t]) + np.dot(self.W,hs[t-1]) + self.b) # hidden state
                os[t] = np.dot(self.V,hs[t]) + self.c # unnormalised log probs for next char
                ycap[t] = self.softmax(os[t]) # probs for next char
            return xs, hs, ycap
        
    def backward(self, xs, hs, ps, targets):
            # backward pass: compute gradients going backwards
            dU, dW, dV = np.zeros_like(self.U), np.zeros_like(self.W), np.zeros_like(self.V)
            db, dc = np.zeros_like(self.b), np.zeros_like(self.c)
            dhnext = np.zeros_like(hs[0])
            for t in reversed(range(self.seq_length)):
                dy = np.copy(ps[t])
                #through softmax
                dy[targets[t]] -= 1 # backprop into y
                #calculate dV, dc
                dV += np.dot(dy, hs[t].T)
                dc += dc
                #dh includes gradient from two sides, next cell and current output
                dh = np.dot(self.V.T, dy) + dhnext # backprop into h
                # backprop through tanh non-linearity 
                dhrec = (1 - hs[t] * hs[t]) * dh  #dhrec is the term used in many equations
                db += dhrec
                #calculate dU and dW
                dU += np.dot(dhrec, xs[t].T)
                dW += np.dot(dhrec, hs[t-1].T)
                #pass the gradient from next cell to the next iteration.
                dhnext = np.dot(self.W.T, dhrec)
            # clip to mitigate exploding gradients
            for dparam in [dU, dW, dV, db, dc]:
                np.clip(dparam, -5, 5, out=dparam) 
            return dU, dW, dV, db, dc
    
    def loss(self, ps, targets):
            """loss for a sequence"""
            # calculate cross-entrpy loss
            return sum(-np.log(ps[t][targets[t],0]) for t in range(self.seq_length))
        
    
    def update_model(self, dU, dW, dV, db, dc):
        # parameter update with adagrad
        for param, dparam, mem in zip([self.U, self.W, self.V, self.b, self.c],
                                  [dU, dW, dV, db, dc],
                                  [self.mU, self.mW, self.mV, self.mb, self.mc]):
            mem += dparam*dparam
            param += -self.learning_rate*dparam/np.sqrt(mem+1e-8) # adagrad update
                
                
    def sample(self, h, seed_ix, n):
            """
            sample a sequence of integers from the model
            h is memory state, seed_ix is seed letter from the first time step
            """
            x = np.zeros((self.vocab_size, 1))
            x[seed_ix] = 1
            ixes = []
            for t in range(n):
                h = np.tanh(np.dot(self.U, x) + np.dot(self.W, h) + self.b)
                y = np.dot(self.V, h) + self.c
                p = np.exp(y)/np.sum(np.exp(y))
                ix = np.random.choice(range(self.vocab_size), p = p.ravel())
                x = np.zeros((self.vocab_size, 1))
                x[ix] = 1
                ixes.append(ix)
            return ixes

    def train(self, data_reader):
            iter_num = 0
            threshold = 0.01
            smooth_loss = -np.log(1.0/data_reader.vocab_size)*self.seq_length
            while (smooth_loss > threshold):
                if data_reader.just_started():
                    hprev = np.zeros((self.hidden_size,1))
                inputs, targets = data_reader.next_batch()
                xs, hs, ps = self.forward(inputs, hprev)
                dU, dW, dV, db, dc = self.backward(xs, hs, ps, targets)
                loss = self.loss(ps, targets)
                self.update_model(dU, dW, dV, db, dc)
                smooth_loss = smooth_loss*0.999 + loss*0.001
                hprev = hs[self.seq_length-1]
                #print every 500 epochs/iterations
                if not iter_num%500: #print every 500 epochs/iterations
                    sample_ix = self.sample(hprev, inputs[0], 200)
                    print( ''.join(data_reader.ix_to_char[ix] for ix in sample_ix))
                    print( "\n\niter :%d, loss:%f"%(iter_num, smooth_loss))
                iter_num += 1

    def predict(self, data_reader, start, n):

        #initialize input vector
        x =  np.zeros((self.vocab_size,1))
        chars = [ch for ch in start]
        ixes = []
        for i in range(len(chars)):
            ix = data_reader.char_to_ix[chars[i]]
            x[ix] = 1
            ixes.append(ix)

        h = np.zeros((self.hidden_size,1))
        # predict next n chars
        for t in range(n):
            h = np.tanh(np.dot(self.U, x) + np.dot(self.W, h) + self.b)
            y = np.dot(self.V, h) + self.c
            p = np.exp(y)/np.sum(np.exp(y))
            ix = np.random.choice(range(self.vocab_size), p = p.ravel())
            x = np.zeros((self.vocab_size,1))
            x[ix] = 1
            ixes.append(ix)
        txt = ''.join(data_reader.ix_to_char[i] for i in ixes)
        return txt

# %%
class DataReader:
    def __init__(self, data, seq_length):
        self.data = data

        #find unique chars
        chars = list(set(self.data))
        #create dictionary mapping for each char
        self.char_to_ix = {ch:i for (i,ch) in enumerate(chars)}
        self.ix_to_char = {i:ch for (i,ch) in enumerate(chars)}
        #total data
        self.data_size = len(self.data)
        #num of unique chars
        self.vocab_size = len(chars)
        self.pointer = 0
        self.seq_length = seq_length

    def next_batch(self):
        input_start = self.pointer
        input_end = self.pointer + self.seq_length
        inputs = [self.char_to_ix[ch] for ch in self.data[input_start:input_end]]
        targets = [self.char_to_ix[ch] for ch in self.data[input_start+1:input_end+1]]
        self.pointer += self.seq_length
        if self.pointer + self.seq_length + 1 >= self.data_size:
            # reset pointer
            self.pointer = 0
        return inputs, targets

    def just_started(self):
        return self.pointer == 0

    def close(self):
        self.fp.close()

# %%
seq_length = 50
test_data = "Discuss how you might use recurrent connections to train a CMAC to output a desired trajectory without using time as an input (e.g., state only). You may earn up to 5 extra homework points if you implement your idea and show that it works. I am not sure how well this will work by having lots of words, hopefully, it will work and get what I want."
# seq_length = len(test_data) #347
# print(seq_length)
data_reader = DataReader(test_data, seq_length)
rnn = RNN(hidden_size=150, vocab_size=data_reader.vocab_size,seq_length=seq_length,learning_rate=0.01)
rnn.train(data_reader)

rnn.predict(data_reader, 'earn', 50)
